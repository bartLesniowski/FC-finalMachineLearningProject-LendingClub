# %% [markdown]
# <h1> PROJEKT KOŃCOWY - MACHINE LEARNING </h1>
# <h4> by Bartłomiej Leśniowski

# %% [markdown]
# * [1. Description of the project](#1.)
# * [2. Data Set Preparation](#2.)
# * [3. Data Processing](#3.)
#  * [3.1. Target feature preparation](#3.1.)
#  * [3.2. Data processing of the rest features](#3.2.)
#   * [3.2.1. Drop features with more than 30% missing values](#3.2.1.)
#   * [3.2.2. Drop features with too much unique categories](#3.2.2.)
#   * [3.2.3. Drop all of features collected after loan origination](#3.2.3.)
#   * [3.2.4. Drop the rest of rows with NaN values](#3.2.4.)
# * [4. Exploratory Data Analysis (EDA)](#4.)
#  * [4.1. Defining functions](#4.1.)
#  * [4.2. Data Analysis](#4.2.)
#   * [4.2.1 loan_amnt (answer 2.f)](#4.2.1.)
#   * [4.2.5 grade, sub_grade](#4.2.5.)
#   * [4.2.6 emp_length (answer 2.e)](#4.2.6.)
#   * [4.2.7 home_ownership (answer 2.c)](#4.2.7.)
#   * [4.2.8 annual_income (answer 2.d)](#4.2.8.)
#   * [4.2.10 issue_d](#4.2.10.)
#   * [4.2.15 dti](#4.2.15.)
#   * [4.2.18 fico_range_low, fico_range_high (answer 2.a amd 2.b)](#4.2.18.)
#   * [4.2.20 pub_rec](#4.2.20.)
#   * [4.2.24 pub_rec_bankruptcies](#4.2.24.)
# * [5. Feature Engineering](#5.)
#  * [5.1. percRepay](#5.1.)
#  * [5.2. Convert target into 1/0 indicator](#5.2.)
#  * [5.3. Training Data preparation](#5.3.)
# * [6. Data for Model Training and Testing preparation](#6.)
#  * [6.1. Dealing with unbalanced class samples](#6.1.)
#  * [6.2. Standarization of the features](#6.2.)
# * [7. Clustering](#7.)
#  * [7.1. K-Means Clustering](#7.1.)
#  * [7.2. Hierarchical Clustering](#7.2.)
#  * [7.3. DBSCAN](#7.3.)
# * [8. Model Training](#8.)
#  * [8.1. Logistic Regression](#8.1.)
#   * [8.1.1. Visualization ROC Curve](#8.1.1.)
#   * [8.1.2. Visualization Learning Curve](#8.1.2.)
#   * [8.1.3. Model Summary](#8.1.3.)
#  * [8.2. Decision Tree](#8.2.)
#   * [8.2.1. Visualization ROC Curve](#8.2.1.)
#   * [8.2.2. Visualization Learning Curve](#8.2.2.)
#   * [8.2.3. Model Summary](#8.2.3.)
#  * [8.3. Random Forest Classifier](#8.3.)
#   * [8.3.1. Visualization ROC Curve](#8.3.1.)
#   * [8.3.2. Visualization Learning Curve](#8.3.2.)
#   * [8.3.3. Model Summary](#8.3.3.)
#  * [8.4. SVM](#8.4.)
#   * [8.4.1. Visualization ROC Curve](#8.4.1.)
#   * [8.4.2. Model Summary](#8.4.2.)
#  * [8.5. K Nearest Neighbors Classifier (KNN)](#8.5.)
#   * [8.5.1. Visualization ROC Curve](#8.5.1.)
#   * [8.5.2. Model Summary](#8.5.2.)
# * [9. Model Training Summary](#9.)
# * [10. PCA](#10.)
#  * [10.1. PCA decomposition preparation](#10.1.)
#  * [10.2. Finding number of component for Final PCA decomposition](#10.2.)
#  * [10.3. Visualization of principal components](#10.3.)
#  * [10.4. Defining functions](#10.4.)
# * [11. Clustering](#11.)
#  * [11.1. KMeans(PCA)](#11.1.)
# * [12. Model Training(PCA)](#12.)
#  * [12.1. Logistic Regresion (PCA)](#12.1.)
#   * [12.1.1. Visualization ROC Curve](#12.1.1.)
#   * [12.1.2. Model Summary](#12.1.2.)
#  * [12.2. Decision Tree (PCA)](#12.2.)
#   * [12.2.1. Visualization ROC Curve](#12.2.1.)
#   * [12.2.2. Model Summary](#12.2.2.)
#  * [12.3. Random Forest (PCA)](#12.3.)
#   * [12.3.1. Visualization ROC Curve](#12.3.1.)
#   * [12.3.2. Model Summary](#12.3.2.)
#  * [12.4. SVM (PCA)](#12.4.)
#   * [12.4.1. Visualization ROC Curve](#12.4.1.)
#   * [12.4.2. Model Summary](#12.4.2.)
#  * [12.5. K Nearest Neighbors Classifier (PCA)](#12.5.)
#   * [12.5.1. Visualization ROC Curve](#12.5.1.)
#   * [12.5.2. Model Summary](#12.5.2.)
# * [13. Summary of all models](#13)
# * [14. Final Model](#14)
# * [15. Conclusions](#15)

# %% [markdown]
# <h2>1. Description of the project
# <a id="1."></a>

# %% [markdown]
# Lending Club to firma pożyczkowa typu peer-to-peer, która łączy pożyczkobiorców z inwestorami za pośrednictwem  platformy  internetowej.  Obsługuje  osoby,  które  potrzebują  pożyczek  osobistych  w wysokości  od  1000do  40  000  USD.  Pożyczkobiorcy  otrzymują  pełną  kwotę  udzielonej  pożyczki pomniejszoną o opłatę początkową, która jest uiszczanafirmie. Inwestorzy kupują weksle zabezpieczone osobistymi pożyczkami i płacą Lending Club opłatę za usługę. FirmaLending  Clubudostępnia dane o wszystkich pożyczkach udzielonych za pośrednictwem swojej platformy w określonych okresach.
# <br><br>
# Na potrzeby tego projektu zostałyużyte dane dotyczące pożyczek udzielonych za pośrednictwem Lending Club na przestrzeni lat 2007 -2011. <b>Każda pożyczka jestopatrzona informacją o tym,czy ostatecznie została spłacona <u>(Fully Paid lub Charged off w kolumnie loan_status)</u>. Twoim zadaniem jest zbudowaniemodelu klasyfikacyjnego, który na podstawie tychdanych będzie przewidywał z określoną dokładnością, czy potencjalny pożyczkobiorca spłaci swój dług z tytułu zaciągniętej pozyczki</b>.Do zbioru danych dołączony jest plik  z  opisem  wszystkich  zmiennych  oraz  plik „FICO  Score  ranged.pdf”, w którym dokładnie opisanoznaczenie jednej z kolumn.
# <br><br>
# Poniżej zaprezentowane są poszczególne etapy analizy, których wykonanie jestkonieczne do zaliczenia projektuoraz ich punktacja:
# <br>
# <ol>
#     <li><b>Obróbka danych(Data Processing)–jako doświadczony Data Scientist zapewne znasz poszczególne kroki, które należy wykonać natym etapie, więc nie będziemy ich tutaj wyszczególniać. W tej części masz do zdobycia 70 pkt.</b></li>
#     <li><b>EDA, czyli obszerna eksploracja danych. Opisz wnioski płynące z każdego wykresu, swoje hipotezy poprzyj testami statystycznymi takimi jak np. t-test lub Chi-square.Dodatkowo odpowiedz na poniższe pytania:</b></li><br>
#     a) W jaki sposób wynik FICO wiąże się z prawdopodobieństwem spłacenia pożyczki przez pożyczkobiorcę?<br>
#     b) W jaki sposób wiek kredytowy wiąże się z prawdopodobieństwem niewykonania zobowiązania i czy ryzyko to jest niezależne lub związane z wynikiem FICO?<br>
#     c) W jaki sposób status kredytu hipotecznego na dom wiąże się z prawdopodobieństwem niewypłacalności?<br>
#     d) W jaki sposób roczny dochód wiąże się z prawdopodobieństwem niewykonania zobowiązania?<br>
#     e) W jaki sposób historia zatrudnienia wiąże się z prawdopodobieństwem niewykonania zobowiązania?<br>
#     f) Jak wielkość żądanej pożyczki jest powiązana z prawdopodobieństwem niewykonania zobowiązania?<br>
#     <li><b>Feature Engineering –utwórz 20 nowych zmiennych(60 pkt)</b></li>
#     <li><b>Modelowanie(150 pkt)</b></li>
# </ol><ol>
#     a) Wykonaj klasteryzację danych (wypróbuj do tego celu kilka metod, min. 3) i sprawdź, czy występują jakieś segmenty pożyczkobiorców, wykorzystaj odpowiednie metody do określenia optymalnej liczby klastrów(40 pkt)<br>
#     b) Wytrenuj 5 różnych modeli,wykorzystując do każdego inny algorytm, a następnie porównaj ich działanie, za metrykę oceny jakości modelu przyjmij AUROC score.(50pkt)<br>
#     c) Sprawdź działanie wcześniej użytych metod na skompresowanych danych za pomocą PCA, porównaj wyniki (AUROC score) z modelamiwytrenowanymi w poprzednim podpunkcie. (20pkt)<br>
#     d) Zbuduj finalny model, którego AUROC score będzie >= 80%, pamiętaj o doborze istotnych zmiennych,kroswalidacji oraz dostrojeniu parametrów modelu,pomyśl również o zbalansowaniu klas. (40pkt)</ol><br>
# <br><br>
# Za całość do zdobycia jest 380 punktów. Do zaliczenia projektu potrzeba minimum 300 pkt.

# %% [markdown]
# <h2> Import necessary libraries and the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import warnings

# %matplotlib inline

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

sns.set()

# %matplotlib inline

# %% [markdown]
# <h2> 2. Data Set preparation
# <a id="2."></a>

# %% [markdown]
# First line in file contains headline - I'll ignore it.

# %%
loanData = pd.read_csv("./Loan_data.csv", header=[1], low_memory=False)
loanData
# Out:
#                                                     id  member_id  loan_amnt  \
# 0                                              1077501        NaN     5000.0
# 1                                              1077430        NaN     2500.0
# 2                                              1077175        NaN     2400.0
# 3                                              1076863        NaN    10000.0
# 4                                              1075358        NaN     3000.0
# ...                                                ...        ...        ...
# 42533                                            72176        NaN     2525.0
# 42534                                            71623        NaN     6500.0
# 42535                                            70686        NaN     5000.0
# 42536  Total amount funded in policy code 1: 460296150        NaN        NaN
# 42537          Total amount funded in policy code 2: 0        NaN        NaN
#
# ...

# %% [markdown]
# Drop last 2 rows.

# %%
loanData.drop(loanData.tail(2).index, inplace=True)

# %% [markdown]
# Check basic info about dataframe

# %%
loanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42536 entries, 0 to 42535
# Columns: 151 entries, id to settlement_term
# dtypes: float64(120), object(31)
# memory usage: 49.3+ MB

# %%
loanData.shape
# Out:
# (42536, 151)

# %% [markdown]
# There are 42536 rows with 151 columns.

# %% [markdown]
# <h2> 3. Data Processing
# <a id="3."></a>

# %% [markdown]
# <h3> 3.1. Target feature preparation
# <a id="3.1."></a>

# %% [markdown]
# Check unique values in target

# %%
loanData['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', nan,
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
loanData['loan_status'].value_counts(dropna = False)
# Out:
# Fully Paid                                             34116
# Charged Off                                             5670
# Does not meet the credit policy. Status:Fully Paid      1988
# Does not meet the credit policy. Status:Charged Off      761
# NaN                                                        1
# Name: loan_status, dtype: int64

# %% [markdown]
# It looks that there is additional infomation about meeting or not with credit policy. In my opinion it's useless. I'll convert it to 2 types:
# <ol>
#     <li> Fully Paid</li>
#     <li> Charged Off</li>
# </ol>

# %%
loanData['loan_status'] = loanData['loan_status'].map({ 'Fully Paid':'Fully Paid', 
                                                           'Charged Off':'Charged Off',
                                                           'Does not meet the credit policy. Status:Fully Paid':'Fully Paid',
                                                            'Does not meet the credit policy. Status:Charged Off':'Charged Off'})

# %% [markdown]
# Let's check how many people paid the whole loan:

# %%
loanData['loan_status'].value_counts(dropna = False)
# Out:
# Fully Paid     36104
# Charged Off     6431
# NaN                1
# Name: loan_status, dtype: int64

# %% [markdown]
# There is 1 null value in that feature.<br>
# 36104 of 42536 has been paid and only 6431 charged off.<br>
# Let's check loan status as percentage:

# %%
loanData['loan_status'].value_counts(normalize=True, dropna=False)
# Out:
# Fully Paid     0.848787
# Charged Off    0.151190
# NaN            0.000024
# Name: loan_status, dtype: float64

# %% [markdown]
# Almost 84,88% is Fully Paid and 15,12% is Charged Off.<br> This target is imbalanced, I'll change it before model training.

# %% [markdown]
# <h4> 3.2. Data processing of the rest features
# <a id="1"></a>

# %% [markdown]
# Check percantage of null values for each feature.

# %%
loanData.isnull().mean().sort_values(ascending=False)
# Out:
# inq_fi                            1.000000
# mths_since_recent_bc              1.000000
# mths_since_recent_inq             1.000000
# mths_since_recent_revol_delinq    1.000000
# num_accts_ever_120_pd             1.000000
#                                     ...
# fico_range_low                    0.000024
# application_type                  0.000024
# debt_settlement_flag              0.000024
# dti                               0.000024
# id                                0.000000
# Length: 151, dtype: float64

# %% [markdown]
# It looks that there is a lot of empty or almost empty columns. I'll visualize it.

# %%
missingValues = loanData.isnull().mean().sort_values(ascending=False)

# %%
plt.figure(figsize=(6,4), dpi = 100)
missingValues.plot.hist(bins=20)
plt.title('Incompleteness of the Feature ')
plt.xlabel('Fraction of deficiency')
plt.ylabel('Feature count')
# Out:
# Text(0, 0.5, 'Feature count')

# %% [markdown]
# On histogram above I can see a huge amount of columns with missing values. I decided to throw away all features with 30% null values.

# %% [markdown]
# <h5>3.2.1. Drop features with more than 30% missing values
# <a id="3.2.1."></a>

# %%
loanData.dropna(thresh = len(loanData) * .7, axis = 1, inplace = True)
loanData.shape
# Out:
# (42536, 59)

# %% [markdown]
# 59 of 151 columns left. Let's check percantage of null values for each feature - again

# %%
loanData.isnull().mean().sort_values(ascending=False)
# Out:
# emp_title                     0.061759
# pub_rec_bankruptcies          0.032114
# emp_length                    0.026166
# chargeoff_within_12_mths      0.003432
# collections_12_mths_ex_med    0.003432
# tax_liens                     0.002492
# revol_util                    0.002139
# last_pymnt_d                  0.001975
# earliest_cr_line              0.000705
# inq_last_6mths                0.000705
# open_acc                      0.000705
# total_acc                     0.000705
# pub_rec                       0.000705
# delinq_2yrs                   0.000705
# delinq_amnt                   0.000705
# acc_now_delinq                0.000705
# title                         0.000329
# annual_inc                    0.000118
# last_credit_pull_d            0.000118
# term                          0.000024
# url                           0.000024
# loan_amnt                     0.000024
# zip_code                      0.000024
# int_rate                      0.000024
# ...

# %% [markdown]
# There are 3 features with more than 1% missing values. I'll check them and then decide what to do with them.

# %%
loanData['emp_title'].describe()
# Out:
# count       39909
# unique      30658
# top       US Army
# freq          139
# Name: emp_title, dtype: object

# %% [markdown]
# There are 30658 unique employee titles. It's imposibble to use it in prediction.<br>
# I'll drop both features.

# %%
loanData.drop(["emp_title"], axis = 1, inplace = True)

# %%
loanData['pub_rec_bankruptcies'].value_counts(dropna = False)
# Out:
# 0.0    39316
# 1.0     1846
# NaN     1366
# 2.0        8
# Name: pub_rec_bankruptcies, dtype: int64

# %% [markdown]
# I decided to fill missing values 0.0, because it's majority in this feature.

# %%
loanData['pub_rec_bankruptcies'].fillna(loanData['pub_rec_bankruptcies'].mode()[0], inplace = True)

# %%
loanData['emp_length'].value_counts(dropna=False)
# Out:
# 10+ years    9369
# < 1 year     5062
# 2 years      4743
# 3 years      4364
# 4 years      3649
# 1 year       3595
# 5 years      3458
# 6 years      2375
# 7 years      1875
# 8 years      1592
# 9 years      1341
# NaN          1113
# Name: emp_length, dtype: int64

# %% [markdown]
# It's difficult to say which value I should fill empty cells. I decided to use forward fill method for this feature. <br>

# %%
loanData['emp_length'] = loanData['emp_length'].fillna(method = 'ffill')

# %%
loanData['emp_length'].value_counts(dropna=False)
# Out:
# 10+ years    9664
# < 1 year     5170
# 2 years      4841
# 3 years      4500
# 4 years      3746
# 1 year       3686
# 5 years      3551
# 6 years      2446
# 7 years      1926
# 8 years      1635
# 9 years      1371
# Name: emp_length, dtype: int64

# %%
loanData.isnull().mean().sort_values(ascending=False)
# Out:
# collections_12_mths_ex_med    0.003432
# chargeoff_within_12_mths      0.003432
# tax_liens                     0.002492
# revol_util                    0.002139
# last_pymnt_d                  0.001975
# pub_rec                       0.000705
# inq_last_6mths                0.000705
# open_acc                      0.000705
# total_acc                     0.000705
# earliest_cr_line              0.000705
# delinq_2yrs                   0.000705
# delinq_amnt                   0.000705
# acc_now_delinq                0.000705
# title                         0.000329
# last_credit_pull_d            0.000118
# annual_inc                    0.000118
# int_rate                      0.000024
# purpose                       0.000024
# dti                           0.000024
# loan_amnt                     0.000024
# funded_amnt                   0.000024
# addr_state                    0.000024
# zip_code                      0.000024
# pymnt_plan                    0.000024
# ...

# %%
loanData.sample(5)
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 5484   985332    10000.0      10000.0          10000.0   36 months    6.03%
# 34018  459766    15000.0      15000.0          14975.0   36 months   13.22%
# 10286  834907     7200.0       7200.0           7200.0   36 months    9.99%
# 21215  647126     5000.0       5000.0           4500.0   36 months   10.36%
# 6219   972662    12000.0      12000.0          11750.0   36 months    7.90%
#
#        installment grade sub_grade emp_length  ... policy_code  \
# 5484        304.36     A        A1    5 years  ...         1.0
# 34018       507.01     C        C2  10+ years  ...         1.0
# 10286       232.29     B        B1    9 years  ...         1.0
# 21215       162.19     B        B5    5 years  ...         1.0
# 6219        375.49     A        A4  10+ years  ...         1.0
#
#        application_type acc_now_delinq chargeoff_within_12_mths delinq_amnt  \
# ...

# %% [markdown]
# <h4> 3.2.2. Drop features with too much unique categories
# <a id="3.2.2."></a>

# %% [markdown]
# Some of columns looks that contain the same value in each row. I'll check it.

# %%
for c in loanData.columns:
    print ("---- %s ---" % c)
    print (loanData[c].value_counts().head(5))
# Out:
# ---- id ---
# 889595    1
# 669286    1
# 788825    1
# 787437    1
# 689052    1
# Name: id, dtype: int64
# ---- loan_amnt ---
# 10000.0    3016
# 12000.0    2439
# 5000.0     2260
# 6000.0     2037
# 15000.0    2012
# Name: loan_amnt, dtype: int64
# ---- funded_amnt ---
# 10000.0    2924
# 12000.0    2347
# 5000.0     2247
# 6000.0     2023
# 15000.0    1897
# Name: funded_amnt, dtype: int64
# ---- funded_amnt_inv ---
# 5000.0     1369
# 10000.0    1302
# 6000.0     1240
# 12000.0    1084
# 8000.0      929
# Name: funded_amnt_inv, dtype: int64
# ---- term ---
#  36 months    31534
#  60 months    11001
# Name: term, dtype: int64
# ---- int_rate ---
#  10.99%    970
#  11.49%    837
#  13.49%    832
#   7.51%    787
#   7.88%    742
# Name: int_rate, dtype: int64
# ---- installment ---
# 311.11    68
# 180.96    59
# 311.02    54
# 150.80    48
# 368.45    46
# Name: installment, dtype: int64
# ---- grade ---
# B    12389
# A    10183
# C     8740
# D     6016
# E     3394
# ...

# %% [markdown]
# These features contains only one value.<ol>
# <li>pymnt_plan
# <li>url
# <li>initial_list_status
# <li>out_prncp
# <li>out_prncp_inv
# <li>collections_12_mths_ex_med
# <li>policy_code
# <li>application_type
# <li>chargeoff_within_12_mths
# <li>delinq_amnt
# <li>tax_liens
# <li>hardship_flag
# <li>disbursement_method
# <li>acc_now_delinq - there are 2 rows with other values
# <li>debt_settlement_flag - 148 rows with other values</ol>
# They will be dropped.

# %%
loanData.drop(['pymnt_plan', 'url', 'initial_list_status', 'out_prncp', 
               'out_prncp_inv', 'collections_12_mths_ex_med','policy_code', 'application_type', 
               'acc_now_delinq', 'chargeoff_within_12_mths','delinq_amnt',  'tax_liens', 
               'hardship_flag', 'disbursement_method', 'debt_settlement_flag'], axis = 1, inplace = True)

# %%
loanData.shape
# Out:
# (42536, 43)

# %% [markdown]
# There are 43 features now. Let's check if there are features with only 1 feature again.

# %%
for c in loanData.columns:
    print ("---- %s ---" % c)
    print (loanData[c].value_counts().head(5))
# Out:
# ---- id ---
# 889595    1
# 669286    1
# 788825    1
# 787437    1
# 689052    1
# Name: id, dtype: int64
# ---- loan_amnt ---
# 10000.0    3016
# 12000.0    2439
# 5000.0     2260
# 6000.0     2037
# 15000.0    2012
# Name: loan_amnt, dtype: int64
# ---- funded_amnt ---
# 10000.0    2924
# 12000.0    2347
# 5000.0     2247
# 6000.0     2023
# 15000.0    1897
# Name: funded_amnt, dtype: int64
# ---- funded_amnt_inv ---
# 5000.0     1369
# 10000.0    1302
# 6000.0     1240
# 12000.0    1084
# 8000.0      929
# Name: funded_amnt_inv, dtype: int64
# ---- term ---
#  36 months    31534
#  60 months    11001
# Name: term, dtype: int64
# ---- int_rate ---
#  10.99%    970
#  11.49%    837
#  13.49%    832
#   7.51%    787
#   7.88%    742
# Name: int_rate, dtype: int64
# ---- installment ---
# 311.11    68
# 180.96    59
# 311.02    54
# 150.80    48
# 368.45    46
# Name: installment, dtype: int64
# ---- grade ---
# B    12389
# A    10183
# C     8740
# D     6016
# E     3394
# ...

# %% [markdown]
# There is 1 feature where all of values are unique - 'id'. I can't use it to predict loan status, I'll drop it.

# %%
loanData.drop(['id'], axis=1, inplace=True)

# %% [markdown]
# <h3> 3.2.3. Drop all of features collected after loan origination
# <a id="3.2.3."></a>

# %%
loanData.columns.to_list()
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
#  'pub_rec_bankruptcies']

# %% [markdown]
# I'll drop all features known after loan has been given.

# %%
loanData.drop(['total_pymnt',
               'total_pymnt_inv',
               'total_rec_prncp',
               'total_rec_int',
               'total_rec_late_fee',
               'recoveries',
               'collection_recovery_fee',
               'last_pymnt_d',
               'last_pymnt_amnt',
               'last_credit_pull_d',
               'last_fico_range_high',
               'last_fico_range_low',
               'funded_amnt_inv',
               'funded_amnt',
               'inq_last_6mths'], axis=1, inplace=True)

# %%
loanData.columns.to_list()
# Out:
# ['loan_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'pub_rec_bankruptcies']

# %% [markdown]
# <h3> 3.2.4. Drop the rest of rows with NaN values.
# <a id="3.2.4."></a>

# %%
loanData['loan_status'].value_counts()
# Out:
# Fully Paid     36104
# Charged Off     6431
# Name: loan_status, dtype: int64

# %% [markdown]
# 36104 rows have Fully Paid and 6431 have Charged Off status.

# %%
loanData.dropna(inplace = True)

# %%
loanData['loan_status'].value_counts()
# Out:
# Fully Paid     36026
# Charged Off     6406
# Name: loan_status, dtype: int64

# %% [markdown]
# The most of dropped rows with any NaN value had Fully Paid (78) status. <br>
# Let's reset index.

# %%
loanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42432 entries, 0 to 42514
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             42432 non-null  float64
#  1   term                  42432 non-null  object
#  2   int_rate              42432 non-null  object
#  3   installment           42432 non-null  float64
#  4   grade                 42432 non-null  object
#  5   sub_grade             42432 non-null  object
#  6   emp_length            42432 non-null  object
#  7   home_ownership        42432 non-null  object
#  8   annual_inc            42432 non-null  float64
#  9   verification_status   42432 non-null  object
#  10  issue_d               42432 non-null  object
#  11  loan_status           42432 non-null  object
#  12  purpose               42432 non-null  object
#  13  title                 42432 non-null  object
#  14  zip_code              42432 non-null  object
# ...

# %%
loanData.shape
# Out:
# (42432, 27)

# %% [markdown]
# There is 27 features and 42432 rows without missing values.

# %% [markdown]
# <h2> 4. Exploratory Data Analysis
# <a id="4"></a>

# %% [markdown]
# <b>EDA, czyli obszerna eksploracja danych. Opisz wnioski płynące z każdego wykresu, swoje hipotezy poprzyj testami statystycznymi takimi jak np. t-test lub Chi-square.Dodatkowo odpowiedz na poniższe pytania:</b></li><br>
#     a) W jaki sposób wynik FICO wiąże się z prawdopodobieństwem spłacenia pożyczki przez pożyczkobiorcę?<br>
#     b) W jaki sposób wiek kredytowy wiąże się z prawdopodobieństwem niewykonania zobowiązania i czy ryzyko to jest niezależne lub związane z wynikiem FICO?<br>
#     c) W jaki sposób status kredytu hipotecznego na dom wiąże się z prawdopodobieństwem niewypłacalności?<br>
#     d) W jaki sposób roczny dochód wiąże się z prawdopodobieństwem niewykonania zobowiązania?<br>
#     e) W jaki sposób historia zatrudnienia wiąże się z prawdopodobieństwem niewykonania zobowiązania?<br>
#     f) Jak wielkość żądanej pożyczki jest powiązana z prawdopodobieństwem niewykonania zobowiązania?<br>

# %%
from scipy import stats

# %% [markdown]
# <h3> 4.1. Defining funcions
# <a id="4.1."></a>

# %% [markdown]
# Visualize a variable without faceting on the loan status.
#
#     col_name is the variable name in the dataframe
#     full_name is the full variable name
#     continuous is True if the variable is continuous, False otherwise

# %%
def plot_var(col_name, full_name, continuous):

    f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)

  
    if continuous:
        sns.boxplot(x=col_name, y='loan_status', data=loanData, ax=ax1)
        ax1.set_ylabel('')
        ax1.set_title(full_name + ' by Loan Status')
    else:
        charge_off_rates = loanData.groupby(col_name)['loan_status'].value_counts(normalize=True).loc[:,'Charged Off']
        sns.barplot(x=charge_off_rates.index, y=charge_off_rates.values, color='#5975A4', saturation=1, ax=ax2)
        ax2.set_ylabel('Fraction of Loans Charged-off')
        ax2.set_title('Charge-off Rate by ' + full_name)
        ax2.set_xlabel(full_name)    

    if continuous:
        sns.histplot(loanData.loc[loanData[col_name].notnull(), col_name])
    else:
        sns.countplot(x = loanData[col_name], order=sorted(loanData[col_name].unique()), 
                      color='#5975A4', saturation=1, ax=ax1)

# %% [markdown]
# <h3> 4.2. Data Analysis
# <a id="4.2."></a>

# %% [markdown]
# I'll inspect all features and if it's necessary modify or drop them.<br>
# For each column I'll provide name and definition from Lending Club Data Dictionary

# %% [markdown]
# <h4> 4.2.1. loan_amnt
# <a id="4.2.1."></a>

# %% [markdown]
# "The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value."

# %%
loanData['loan_amnt'].describe()
# Out:
# count    42432.000000
# mean     11103.857348
# std       7411.018732
# min        500.000000
# 25%       5200.000000
# 50%       9800.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %% [markdown]
# The range of loan amount is from 500$  to  35000$, median is 9800$.<br>
# Let's check if there are some differencies grouped by our target.

# %%
loanData.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                count          mean          std    min     25%      50%  \
# loan_status
# Charged Off   6406.0  11860.326257  7970.991495  500.0  5500.0  10000.0
# Fully Paid   36026.0  10969.345056  7298.866286  500.0  5200.0   9600.0
#
#                  75%      max
# loan_status
# Charged Off  16000.0  35000.0
# Fully Paid   15000.0  35000.0

# %%
plot_var('loan_amnt', 'Loan Amount', continuous=True)

# %% [markdown]
# <b>f) Jak wielkość żądanej pożyczki jest powiązana z prawdopodobieństwem niewykonania zobowiązania?

# %%
loanData.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                count          mean          std    min     25%      50%  \
# loan_status
# Charged Off   6406.0  11860.326257  7970.991495  500.0  5500.0  10000.0
# Fully Paid   36026.0  10969.345056  7298.866286  500.0  5200.0   9600.0
#
#                  75%      max
# loan_status
# Charged Off  16000.0  35000.0
# Fully Paid   15000.0  35000.0

# %% [markdown]
# Higher loan amount has higher probability to be Charged Off.

# %% [markdown]
# <h4> 4.2.2. term

# %% [markdown]
# The number of payments on the loan. Values are in months and can be either 36 or 60.

# %%
loanData['term'].value_counts()
# Out:
#  36 months    31439
#  60 months    10993
# Name: term, dtype: int64

# %%
loanData['term'].value_counts(normalize=True)
# Out:
#  36 months    0.740927
#  60 months    0.259073
# Name: term, dtype: float64

# %% [markdown]
# Let's compare loan status by term.

# %%
loanData.groupby('term')['loan_status'].value_counts(normalize=True)
# Out:
# term        loan_status
#  36 months  Fully Paid     0.877350
#             Charged Off    0.122650
#  60 months  Fully Paid     0.768034
#             Charged Off    0.231966
# Name: loan_status, dtype: float64

# %%
loanData['term'] = loanData['term'].str.strip('months').astype(int)

# %%
plot_var('term', 'Term', continuous=False)

# %% [markdown]
# 87,74% of 3year and 76,80% of 5year loans have been paid, the rest is Charged Off. Loans with longer term has higher probability to be Charded Off.

# %% [markdown]
# <h4> 4.2.3. int_rate

# %% [markdown]
# Interest Rate on the loan.

# %%
loanData['int_rate'].describe()
# Out:
# count       42432
# unique        394
# top        10.99%
# freq          970
# Name: int_rate, dtype: object

# %% [markdown]
# I'll strip "%" and convert to float.

# %%
loanData['int_rate'] = loanData['int_rate'].str.strip('%').astype(float)

# %%
loanData['int_rate'].describe()
# Out:
# count    42432.000000
# mean        12.161955
# std          3.707475
# min          5.420000
# 25%          9.630000
# 50%         11.990000
# 75%         14.720000
# max         24.590000
# Name: int_rate, dtype: float64

# %% [markdown]
# The lowest interest rate is 5,42% and highest is equal to 24.59%<br>
# Let's vizualize it.

# %%
plot_var('int_rate', 'Interest Rate', continuous=True)

# %%
loanData.groupby('loan_status')['int_rate'].describe()
# Out:
#                count       mean       std   min    25%    50%    75%    max
# loan_status
# Charged Off   6406.0  13.923011  3.561015  5.42  11.49  13.80  16.40  24.40
# Fully Paid   36026.0  11.848811  3.644925  5.42   8.90  11.71  14.27  24.59

# %% [markdown]
# Fully Paid loans has lower avarage interest rate.

# %% [markdown]
# <h4> 4.2.4. installment

# %% [markdown]
# The monthly payment owed by the borrower if the loan originates.

# %% [markdown]
# Let's see main informations about installment.

# %%
loanData['installment'].describe()
# Out:
# count    42432.000000
# mean       323.003033
# std        208.941527
# min         15.670000
# 25%        165.740000
# 50%        278.195000
# 75%        428.677500
# max       1305.190000
# Name: installment, dtype: float64

# %% [markdown]
# Mean value is 323,00$, min 15,67$ and max 1305,19$<br>
# Let's check grouped by target.

# %%
plot_var('installment', 'Installment', continuous=True)

# %% [markdown]
# This feature has a lot of outliers. They starts around 900 for "Fully Paid" loan status and between 850-900 for "Charged Off". I'll  drop installment equal or higher than 900$ later.

# %%
loanData = loanData.drop(loanData[(loanData['installment']>=900)].index).reset_index(drop=True)

# %%
loanData.groupby('loan_status')['installment'].describe()
# Out:
#                count        mean         std    min       25%     50%     75%  \
# loan_status
# Charged Off   6300.0  322.669687  200.889953  15.91  167.1250  284.16  439.09
# Fully Paid   35570.0  312.026164  192.097311  15.67  164.0275  273.40  414.09
#
#                 max
# loan_status
# Charged Off  898.55
# Fully Paid   899.52

# %% [markdown]
# Charged Off status has higher mean and median installment.

# %% [markdown]
# <h4> 4.2.5. grade and sub_grade
# <a id="4.2.5."></a>

# %% [markdown]
# Grade - LC assigned loan grade<br>
# Sub_grade - LC assigned loan subgrade

# %% [markdown]
# Let's check unique values grade and sub_grade.

# %%
loanData['grade'].unique()
# Out:
# array(['B', 'C', 'A', 'E', 'F', 'D', 'G'], dtype=object)

# %%
plot_var('grade', 'Loan Amount', continuous=False)

# %% [markdown]
# "A" grade has the lowest and "G" has charge-off rate. I suppose that "A" is the best and "G" the worst grade.

# %%
loanData['sub_grade'].unique()
# Out:
# array(['B2', 'C4', 'C5', 'C1', 'B5', 'A4', 'E1', 'F2', 'C3', 'B1', 'D1',
#        'A1', 'B3', 'B4', 'C2', 'D2', 'A3', 'A5', 'D5', 'A2', 'E4', 'D3',
#        'D4', 'F3', 'E3', 'F4', 'F1', 'E5', 'G4', 'E2', 'G3', 'G2', 'G1',
#        'F5', 'G5'], dtype=object)

# %%
plot_var('sub_grade', 'Loan Amount', continuous=False)

# %% [markdown]
# Sub_grade is extended feature of grade. I decided to drop "grade".

# %%
loanData.drop(['grade'], axis = 1, inplace = True)

# %% [markdown]
# With consecutive letters and numbers Charge-Off Rate is increasing.

# %% [markdown]
# <h4>4.2.6. emp_length
# <a id="4.2.6."></a>

# %% [markdown]
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %%
loanData['emp_length'].value_counts(dropna=False)
# Out:
# 10+ years    9455
# < 1 year     5096
# 2 years      4782
# 3 years      4449
# 4 years      3687
# 1 year       3644
# 5 years      3495
# 6 years      2411
# 7 years      1893
# 8 years      1601
# 9 years      1357
# Name: emp_length, dtype: int64

# %% [markdown]
# Values doesn't match with description, there are "< 1 year" and "10+ years". I'll replace them with "0 year" and "10 years".

# %%
loanData['emp_length'].replace(to_replace='10+ years', value='10 years', inplace=True)
loanData['emp_length'].replace(to_replace='< 1 year', value='0 year', inplace=True)

# %% [markdown]
# Let's check eployment length grouped by loan status.

# %%
plot_var('emp_length', 'Employment length', continuous=False)

# %%
loanData.groupby('emp_length')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# emp_length
# 9 years     0.137804
# 2 years     0.139063
# 4 years     0.145647
# 5 years     0.147353
# 6 years     0.147657
# 3 years     0.147674
# 0 year      0.148940
# 1 year      0.153128
# 8 years     0.153654
# 7 years     0.156366
# 10 years    0.161185
# Name: loan_status, dtype: float64

# %% [markdown]
# <b>e) W jaki sposób historia zatrudnienia wiąże się z prawdopodobieństwem niewykonania zobowiązania?

# %% [markdown]
# Employment length doesn't affect on loan status. Borrowers employed 10 or more years have 16,11% chance to Charge Off loans, it's the highest Charge off rate, 7 years has 15,64% chance but 1 year has 15,31%. The lowest Charged Off rate have 9 years and 2 years employment length below 14%.

# %% [markdown]
# <h4> 4.2.7. home_ownership
# <a id="4.2.7."></a>

# %% [markdown]
# The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER.

# %%
loanData['home_ownership'].value_counts(dropna=False)
# Out:
# RENT        19970
# MORTGAGE    18558
# OWN          3205
# OTHER         133
# NONE            4
# Name: home_ownership, dtype: int64

# %% [markdown]
# There are only 4 values with "NONE" values, I'll replace them with "OTHER" value.

# %%
loanData['home_ownership'].replace(['NONE'], 'OTHER', inplace = True)

# %%
plot_var('home_ownership', 'Home ownership', continuous = False)

# %% [markdown]
# RENT, OWN, MORTGAGE values have almost equal Charge Off Rates, OTHER home ownership status has higher probability of Charge Off.

# %% [markdown]
# <b>c) W jaki sposób status kredytu hipotecznego na dom wiąże się z prawdopodobieństwem niewypłacalności?

# %%
loanData.groupby('home_ownership')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# home_ownership
# MORTGAGE    0.141287
# OWN         0.151950
# RENT        0.158338
# OTHER       0.211679
# Name: loan_status, dtype: float64

# %% [markdown]
# Loans with MORTGAGE home ownership have the lowest Charge Off rate (14.21%)

# %% [markdown]
# <h4> 4.2.8. annual_inc
# <a id="4.2.8."></a>

# %%
loanData['annual_inc'].describe()
# Out:
# count    4.187000e+04
# mean     6.822273e+04
# std      6.285442e+04
# min      1.896000e+03
# 25%      4.000000e+04
# 50%      5.800000e+04
# 75%      8.100000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# The lowest income is 1896 and the highest 6000000

# %%
plot_var('annual_inc', 'Annual Income', continuous = True)

# %% [markdown]
# There are too much of outliers, I'll drop rows with Anual Income equal and higher than 140000$.

# %%
loanData = loanData.drop(loanData[(loanData['annual_inc']>=140000)].index).reset_index(drop=True)

# %%
plot_var('annual_inc', 'Annual Income', continuous = True)

# %%
loanData.groupby('loan_status')['annual_inc'].describe()
# Out:
#                count          mean           std     min      25%      50%  \
# loan_status
# Charged Off   6026.0  55739.843628  26042.311086  2000.0  36000.0  51000.0
# Fully Paid   33615.0  60906.706895  27262.690731  1896.0  40000.0  56400.0
#
#                  75%       max
# loan_status
# Charged Off  70000.0  139720.0
# Fully Paid   78000.0  139992.0

# %% [markdown]
# <b>d) W jaki sposób roczny dochód wiąże się z prawdopodobieństwem niewykonania zobowiązania?

# %% [markdown]
# Borrowers with lower annual income have higher probability of Charge Off the loans.

# %% [markdown]
# <h4> 4.2.9. verification_status

# %% [markdown]
# Indicates if income was verified by LC, not verified, or if the income source was verified

# %%
loanData['verification_status'].value_counts()
# Out:
# Not Verified       18109
# Verified           11911
# Source Verified     9621
# Name: verification_status, dtype: int64

# %% [markdown]
# "Not verified" source of income is the most popular. Let's check Charge Off Rate and compare Verification status by Fully Paid and Charge Off status.

# %%
plot_var('verification_status', 'Verification Status', continuous = False)

# %%
loanData.groupby('verification_status')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# verification_status
# Not Verified       0.140483
# Source Verified    0.150920
# Verified           0.170431
# Name: loan_status, dtype: float64

# %% [markdown]
# Verified status has the highest Charge Off Rate.

# %% [markdown]
# <h4> 4.2.10. issue_d
# <a id="4.2.10."></a>

# %% [markdown]
# The month which the loan was funded

# %%
loanData['issue_d'].sample(5)
# Out:
# 9015     Aug-2011
# 36273    Apr-2008
# 7709     Sep-2011
# 9991     Jul-2011
# 22400    Oct-2010
# Name: issue_d, dtype: object

# %%
loanData['issue_d'].value_counts()
# Out:
# Dec-2011    2125
# Nov-2011    2041
# Oct-2011    1913
# Sep-2011    1884
# Aug-2011    1781
# Jul-2011    1740
# Jun-2011    1684
# May-2011    1589
# Apr-2011    1468
# Mar-2011    1344
# Jan-2011    1310
# Dec-2010    1257
# Feb-2011    1226
# Nov-2010    1166
# Oct-2010    1157
# Jul-2010    1153
# Aug-2010    1115
# Sep-2010    1107
# Jun-2010    1044
# May-2010     944
# Apr-2010     861
# Mar-2010     771
# Feb-2010     632
# Nov-2009     614
# Jan-2010     611
# Dec-2009     598
# Oct-2009     561
# Sep-2009     476
# Aug-2009     424
# Jun-2009     383
# Jul-2009     382
# Mar-2008     378
# May-2009     340
# Apr-2009     316
# Mar-2009     309
# Jan-2008     289
# Feb-2008     288
# Feb-2009     288
# Jan-2009     254
# Apr-2008     239
# Dec-2008     232
# Nov-2008     198
# Dec-2007     159
# Jul-2008     134
# Jun-2008     118
# May-2008     112
# Oct-2008     111
# Nov-2007     105
# Oct-2007     101
# Aug-2008      93
# Aug-2007      60
# Sep-2008      52
# ...

# %% [markdown]
# These Lending Club data contains information between August 2007 and December 2011. I'll create 2 another features and drop original column.

# %%
loanData['monthFunded'] = loanData['issue_d'].apply(lambda s: str(s[:3]))

# %%
yearFunded = loanData['issue_d'].apply(lambda s: int(s[-4:]))

# %%
yearFunded.value_counts()
# Out:
# 2011    20105
# 2010    11818
# 2009     4945
# 2008     2244
# 2007      529
# Name: issue_d, dtype: int64

# %% [markdown]
# There is increasing trend with the year.

# %%
loanData['monthFunded'].value_counts()
# Out:
# Dec    4371
# Nov    4124
# Oct    3843
# Sep    3569
# Aug    3473
# Jul    3460
# Jun    3232
# May    2985
# Apr    2884
# Mar    2802
# Jan    2464
# Feb    2434
# Name: monthFunded, dtype: int64

# %% [markdown]
# Exept January and February with each successive month, the number of loans increases.<br>
# I can drop original feature.

# %%
loanData.drop(['issue_d'], axis = 1, inplace = True)

# %% [markdown]
# <h4>4.2.11. purpose

# %% [markdown]
# A category provided by the borrower for the loan request.

# %%
loanData['purpose'].value_counts()
# Out:
# debt_consolidation    18588
# credit_card            5110
# other                  4140
# home_improvement       2789
# major_purchase         2171
# small_business         1773
# car                    1552
# wedding                 958
# medical                 698
# moving                  595
# educational             401
# vacation                387
# house                   383
# renewable_energy         96
# Name: purpose, dtype: int64

# %%
loanData.groupby('purpose')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# purpose
# wedding               0.108559
# major_purchase        0.108706
# car                   0.109536
# credit_card           0.113307
# home_improvement      0.136608
# vacation              0.149871
# debt_consolidation    0.156499
# house                 0.161880
# other                 0.170773
# medical               0.174785
# moving                0.174790
# renewable_energy      0.187500
# educational           0.211970
# small_business        0.276932
# Name: loan_status, dtype: float64

# %% [markdown]
# 10,86% loans taken because of wedding were not been fully paid, on the other side are small businesses where 27,69% were charge off.

# %% [markdown]
# <h4>4.2.12. title

# %% [markdown]
# The loan title provided by the borrower.

# %%
loanData['title'].describe()
# Out:
# count                  39641
# unique                 20056
# top       Debt Consolidation
# freq                    2089
# Name: title, dtype: object

# %% [markdown]
# There are 20056 unique titles, this feature couldn't be used to predict the target. I'll drop it.

# %%
loanData.drop(['title'], axis = 1, inplace = True)

# %% [markdown]
# <h4>4.2.13. zip_code

# %% [markdown]
# The first 3 numbers of the zip code provided by the borrower in the loan application.

# %%
loanData['zip_code'].sample(5)
# Out:
# 3401     105xx
# 3220     787xx
# 36496    527xx
# 11106    770xx
# 2746     100xx
# Name: zip_code, dtype: object

# %%
loanData['zip_code'].describe()
# Out:
# count     39641
# unique      830
# top       100xx
# freq        531
# Name: zip_code, dtype: object

# %% [markdown]
# There are 830 different zip codes, I'll drop it.

# %%
loanData.drop(['zip_code'], axis = 1, inplace = True)

# %% [markdown]
# <h4>4.2.14. addr_state

# %% [markdown]
# The state provided by the borrower in the loan application

# %%
loanData['addr_state'].sample(5)
# Out:
# 9572     KS
# 33500    TX
# 22933    NY
# 33959    SD
# 32579    CA
# Name: addr_state, dtype: object

# %%
loanData['addr_state'].value_counts()
# Out:
# CA    6881
# NY    3751
# FL    2917
# TX    2655
# NJ    1815
# PA    1574
# IL    1568
# VA    1391
# GA    1389
# MA    1313
# OH    1269
# MD    1034
# AZ     868
# WA     832
# CO     811
# NC     779
# MI     754
# CT     741
# MO     727
# MN     619
# NV     493
# WI     486
# SC     461
# AL     460
# OR     454
# LA     430
# KY     341
# OK     303
# KS     281
# UT     262
# AR     248
# DC     201
# RI     200
# NM     198
# WV     181
# NH     174
# HI     168
# DE     128
# MT      93
# WY      84
# AK      75
# SD      66
# VT      56
# TN      31
# MS      26
# IN      19
# IA      12
# NE      11
# ID       8
# ME       3
# Name: addr_state, dtype: int64

# %%
loanData.groupby('addr_state')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# addr_state
# WY    0.047619
# DC    0.069652
# DE    0.109375
# AL    0.123913
# KS    0.124555
# VT    0.125000
# ID    0.125000
# TX    0.126554
# WV    0.127072
# OH    0.127660
# LA    0.127907
# CO    0.129470
# RI    0.130000
# MA    0.130998
# VA    0.131560
# AR    0.133065
# CT    0.134953
# PA    0.135324
# NY    0.139429
# IL    0.140944
# OK    0.141914
# MN    0.145396
# SC    0.147505
# WI    0.148148
# NH    0.149425
# MI    0.149867
# MT    0.150538
# AZ    0.152074
# KY    0.152493
# UT    0.152672
# NC    0.159178
# NJ    0.162534
# OR    0.162996
# GA    0.165587
# WA    0.165865
# MD    0.166344
# HI    0.166667
# IA    0.166667
# NM    0.166667
# CA    0.166982
# MO    0.185695
# FL    0.186493
# TN    0.193548
# SD    0.196970
# AK    0.200000
# MS    0.230769
# NV    0.233266
# IN    0.368421
# NE    0.545455
# Name: loan_status, dtype: float64

# %% [markdown]
# Only 4,76% of loans taken in Wyoming is Charge Off, on the other hand more than half (54,55%) of loans taken in Nebraska were not fully paid.

# %% [markdown]
# I'll divide states on regions of the USA.

# %%
west = ['CA', 'OR', 'UT','WA', 'CO', 'NV', 'AK', 'MT', 'HI', 'WY', 'ID']
south_west = ['AZ', 'TX', 'NM', 'OK']
south_east = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE', 'MS', 'TN' ]
mid_west = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
north_east = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']

# %%
loanData['region'] = np.nan

def finding_regions(state):
    if state in west:
        return 'West'
    elif state in south_west:
        return 'SouthWest'
    elif state in south_east:
        return 'SouthEast'
    elif state in mid_west:
        return 'MidWest'
    elif state in north_east:
        return 'NorthEast'
    
loanData['region'] = loanData['addr_state'].apply(finding_regions)

# %%
loanData.drop(['addr_state'], axis = 1, inplace = True)

# %%
loanData['region'].value_counts()
# Out:
# NorthEast    10661
# West         10161
# SouthEast     8983
# MidWest       5812
# SouthWest     4024
# Name: region, dtype: int64

# %%
loanData.groupby('region')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# region
# SouthWest    0.135189
# NorthEast    0.143889
# MidWest      0.147281
# SouthEast    0.156852
# West         0.165633
# Name: loan_status, dtype: float64

# %% [markdown]
# More loans were charged off in West and South East region the lowest rate is in South West region.

# %% [markdown]
# <h4>4.2.15. dti
# <a id="4.2.15."></a>

# %% [markdown]
# A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.

# %%
loanData['dti'].sample(5)
# Out:
# 27518     3.06
# 29422    16.68
# 23062    15.42
# 14667     6.00
# 5886     19.02
# Name: dti, dtype: float64

# %%
loanData['dti'].describe()
# Out:
# count    39641.000000
# mean        13.544809
# std          6.721703
# min          0.000000
# 25%          8.400000
# 50%         13.690000
# 75%         18.860000
# max         29.990000
# Name: dti, dtype: float64

# %% [markdown]
# The lowest ratio is 0.0 and the highest is 29,99. Let's vizualize it.

# %%
plot_var('dti', 'dti', continuous = True)

# %%
loanData.groupby('loan_status')['dti'].describe()
# Out:
#                count       mean       std  min   25%    50%      75%    max
# loan_status
# Charged Off   6026.0  14.159512  6.662025  0.0  9.20  14.47  19.5275  29.85
# Fully Paid   33615.0  13.434614  6.726509  0.0  8.27  13.54  18.7300  29.99

# %% [markdown]
# Charged Off status has higher avarage debt-to-income ratio.

# %% [markdown]
# <h4>4.2.16. delinq_2yrs

# %% [markdown]
# The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years

# %%
loanData['delinq_2yrs'].sample(5)
# Out:
# 14117    0.0
# 18586    0.0
# 5495     0.0
# 15836    0.0
# 9436     0.0
# Name: delinq_2yrs, dtype: float64

# %%
loanData['delinq_2yrs'].describe()
# Out:
# count    39641.000000
# mean         0.150602
# std          0.508577
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         13.000000
# Name: delinq_2yrs, dtype: float64

# %%
loanData['delinq_2yrs'].value_counts(normalize = True)
# Out:
# 0.0     0.889786
# 1.0     0.083928
# 2.0     0.017608
# 3.0     0.005777
# 4.0     0.001690
# 5.0     0.000580
# 6.0     0.000328
# 7.0     0.000151
# 8.0     0.000076
# 13.0    0.000025
# 11.0    0.000025
# 9.0     0.000025
# Name: delinq_2yrs, dtype: float64

# %% [markdown]
# Almost 88,98% borrowers has no 30+ days and 8,39% has 1 delinquency.<br>
# Let's group by loan status.

# %%
loanData.groupby('loan_status')['delinq_2yrs'].describe()
# Out:
#                count      mean       std  min  25%  50%  75%   max
# loan_status
# Charged Off   6026.0  0.173249  0.540344  0.0  0.0  0.0  0.0   8.0
# Fully Paid   33615.0  0.146542  0.502571  0.0  0.0  0.0  0.0  13.0

# %% [markdown]
# Charged Off status has higher mean value, but Fully Paid has maximum value (13.0).

# %% [markdown]
# <h4>4.2.17. earliest_cr_line

# %% [markdown]
# The month the borrower's earliest reported credit line was opened

# %%
loanData['earliest_cr_line'].sample(5)
# Out:
# 26496    Jun-1997
# 17045    Mar-2002
# 30053    Dec-1996
# 17807    Jun-2004
# 18505    Nov-2003
# Name: earliest_cr_line, dtype: object

# %% [markdown]
# It might be usefull to know the year of the first loan taken by the borrower. I'll separate it and drop original feature.

# %%
loanData['earliestYear'] = loanData['earliest_cr_line'].apply(lambda s: int(s[-4:]))

# %%
loanData.groupby('loan_status')['earliestYear'].describe()
# Out:
#                count         mean       std     min     25%     50%     75%  \
# loan_status
# Charged Off   6026.0  1997.115168  6.712941  1962.0  1994.0  1998.0  2002.0
# Fully Paid   33615.0  1996.796162  6.768998  1946.0  1994.0  1998.0  2001.0
#
#                 max
# loan_status
# Charged Off  2008.0
# Fully Paid   2008.0

# %%
plot_var('earliestYear', 'earliestYear', continuous = True)

# %% [markdown]
# People who have taken thair first loan faster are more likely to pay full loan.

# %%
loanData.drop(['earliest_cr_line'], axis = 1, inplace = True)

# %% [markdown]
# <h4>4.3.18. fico_range_low, fico_range_high
#     <a id="4.2.18."></a>

# %% [markdown]
# fico_range_low - The lower boundary range the borrower’s FICO at loan origination belongs to<br>
# fico_range_high - The upper boundary range the borrower’s FICO at loan origination belongs to

# %%
loanData[['fico_range_low', 'fico_range_high']].sample(5)
# Out:
#        fico_range_low  fico_range_high
# 6863            730.0            734.0
# 30086           710.0            714.0
# 12774           745.0            749.0
# 19641           670.0            674.0
# 16956           730.0            734.0

# %%
loanData[['fico_range_low', 'fico_range_high']].describe()
# Out:
#        fico_range_low  fico_range_high
# count    39641.000000     39641.000000
# mean       712.799501       716.799501
# std         36.081479        36.081479
# min        610.000000       614.000000
# 25%        685.000000       689.000000
# 50%        710.000000       714.000000
# 75%        740.000000       744.000000
# max        825.000000       829.000000

# %%
loanData.groupby('loan_status')['fico_range_low'].describe()
# Out:
#                count        mean        std    min    25%    50%    75%    max
# loan_status
# Charged Off   6026.0  701.047129  32.202014  615.0  675.0  695.0  725.0  820.0
# Fully Paid   33615.0  714.906292  36.334476  610.0  685.0  710.0  740.0  825.0

# %%
loanData.groupby('loan_status')['fico_range_high'].describe()
# Out:
#                count        mean        std    min    25%    50%    75%    max
# loan_status
# Charged Off   6026.0  705.047129  32.202014  619.0  679.0  699.0  729.0  824.0
# Fully Paid   33615.0  718.906292  36.334476  614.0  689.0  714.0  744.0  829.0

# %%
plot_var('fico_range_high', 'fico_range_high', continuous = True)

# %% [markdown]
# Let's check correlation between them.

# %%
loanData[['fico_range_low','fico_range_high']].corr()
# Out:
#                  fico_range_low  fico_range_high
# fico_range_low              1.0              1.0
# fico_range_high             1.0              1.0

# %% [markdown]
# I need only one feature. I'll calculate avarage value of them and drop both of original features.

# %%
loanData['ficoScore'] = 0.5*loanData['fico_range_low'] + 0.5*loanData['fico_range_high']

# %%
loanData['ficoScore'].sample(5)
# Out:
# 32913    712.0
# 21510    727.0
# 39       762.0
# 12546    727.0
# 1645     697.0
# Name: ficoScore, dtype: float64

# %%
plot_var('ficoScore', 'FICO Score', continuous = True)

# %%
loanData.groupby('loan_status')['ficoScore'].describe()
# Out:
#                count        mean        std    min    25%    50%    75%    max
# loan_status
# Charged Off   6026.0  703.047129  32.202014  617.0  677.0  697.0  727.0  822.0
# Fully Paid   33615.0  716.906292  36.334476  612.0  687.0  712.0  742.0  827.0

# %%
loanData.drop(['fico_range_low','fico_range_high'], axis = 1, inplace = True)

# %% [markdown]
# <b>a) W jaki sposób wynik FICO wiąże się z prawdopodobieństwem spłacenia pożyczki przez pożyczkobiorcę?

# %% [markdown]
# The lower FICO score, the greater likelihood of charge off the loan.

# %% [markdown]
# <b>b) W jaki sposób wiek kredytowy wiąże się z prawdopodobieństwem niewykonania zobowiązania i czy ryzyko to jest niezależne lub związane z wynikiem FICO?

# %%
loanData['CreditAge'] = yearFunded - loanData['earliestYear']

# %%
loanData.groupby('loan_status')['CreditAge'].describe()
# Out:
#                count       mean       std  min  25%   50%   75%   max
# loan_status
# Charged Off   6026.0  13.067873  6.761537  0.0  9.0  12.0  16.0  49.0
# Fully Paid   33615.0  13.441291  6.806783  0.0  9.0  12.0  17.0  65.0

# %%
loanData.groupby('loan_status')['ficoScore'].describe()
# Out:
#                count        mean        std    min    25%    50%    75%    max
# loan_status
# Charged Off   6026.0  703.047129  32.202014  617.0  677.0  697.0  727.0  822.0
# Fully Paid   33615.0  716.906292  36.334476  612.0  687.0  712.0  742.0  827.0

# %% [markdown]
# One of the most important categories in FICO scoring is Credit Age - higher Credit Age, more scores borrower will gain. Mean and maximum Credit Age and FICO Score confirmed that dependence.

# %% [markdown]
# <h4>4.2.19. open_acc

# %% [markdown]
# The number of open credit lines in the borrower's credit file.

# %%
loanData['open_acc'].sample(5)
# Out:
# 34265     8.0
# 6197     17.0
# 3394     16.0
# 27269     8.0
# 7467      7.0
# Name: open_acc, dtype: float64

# %%
loanData['open_acc'].describe()
# Out:
# count    39641.000000
# mean         9.201433
# std          4.416767
# min          1.000000
# 25%          6.000000
# 50%          8.000000
# 75%         12.000000
# max         44.000000
# Name: open_acc, dtype: float64

# %%
loanData.groupby('loan_status')['open_acc'].describe()
# Out:
#                count      mean       std  min  25%  50%   75%   max
# loan_status
# Charged Off   6026.0  9.137571  4.557224  1.0  6.0  8.0  12.0  38.0
# Fully Paid   33615.0  9.212881  4.391085  1.0  6.0  8.0  12.0  44.0

# %%
plot_var('open_acc','Opened credit lines', continuous = True)

# %% [markdown]
# I'll drop outliers higher than 24.

# %%
loanData = loanData.drop(loanData[(loanData['open_acc']>24)].index).reset_index(drop=True)

# %%
plot_var('open_acc','Opened credit lines', continuous = True)

# %%
loanData.groupby('loan_status')['open_acc'].describe()
# Out:
#                count      mean       std  min  25%  50%   75%   max
# loan_status
# Charged Off   5985.0  9.006850  4.280184  1.0  6.0  8.0  11.0  24.0
# Fully Paid   33456.0  9.123745  4.198824  1.0  6.0  8.0  12.0  24.0

# %% [markdown]
# H0: the means of the samples are equal.<br>
# H1: the means of the samples are unequal.

# %%
from scipy.stats import ttest_ind
data1 = loanData[loanData['loan_status'] == 1]['open_acc']
data2 = loanData[loanData['loan_status'] == 0]['open_acc']
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=1.995, p=0.046
# Probably different distributions

# %% [markdown]
# There is no significant difference in number of credit lines between fully paid loans and charged-off loans, but mean of Fully Paid loan status is higher.

# %% [markdown]
# <h4>4.2.20. pub_rec
#     <a id="4.2.20."></a>

# %% [markdown]
# Number of derogatory public records

# %%
loanData['pub_rec'].sample(5)
# Out:
# 37541    0.0
# 35928    0.0
# 1707     1.0
# 9940     0.0
# 12474    0.0
# Name: pub_rec, dtype: float64

# %%
loanData['pub_rec'].value_counts(normalize = True)
# Out:
# 0.0    0.942319
# 1.0    0.055856
# 2.0    0.001521
# 3.0    0.000228
# 4.0    0.000051
# 5.0    0.000025
# Name: pub_rec, dtype: float64

# %% [markdown]
# Most of borrowers (94,23%) don't have or have 1 (5,58%) derogatory public records. <br>
# Is there any difference between fully paid loans and charged-off loans in that feature?

# %%
loanData.groupby('loan_status')['pub_rec'].describe()
# Out:
#                count      mean       std  min  25%  50%  75%  max
# loan_status
# Charged Off   5985.0  0.092231  0.296224  0.0  0.0  0.0  0.0  2.0
# Fully Paid   33456.0  0.054131  0.238749  0.0  0.0  0.0  0.0  5.0

# %%
plot_var('pub_rec','Public records', continuous = True)

# %%
loanData['pub_rec'].value_counts()
# Out:
# 0.0    37166
# 1.0     2203
# 2.0       60
# 3.0        9
# 4.0        2
# 5.0        1
# Name: pub_rec, dtype: int64

# %% [markdown]
# Most values is 0.0 or 1.0. I'll convert all values into categories:<br>
# 0.0 - there is no derogatory public records;<br>
# 1.0 - there are at least 1 derogatory public record.

# %%
loanData['pub_rec'] = loanData['pub_rec'].map({0.0 : 0, 1.0 : 1, 2.0 : 1, 3.0 : 1, 4.0 : 1, 5.0 : 1})

# %%
plot_var('pub_rec','Public records', continuous = False)

# %%
loanData['pub_rec'].value_counts()
# Out:
# 0    37166
# 1     2275
# Name: pub_rec, dtype: int64

# %%
loanData['pub_rec'].value_counts(normalize = True)
# Out:
# 0    0.942319
# 1    0.057681
# Name: pub_rec, dtype: float64

# %% [markdown]
# 5,74% loans had at least 1 derogatory record. How it looks grouped by Charged Off loan status?

# %%
loanData.groupby('pub_rec')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values()
# Out:
# pub_rec
# 0    0.146505
# 1    0.237363
# Name: loan_status, dtype: float64

# %% [markdown]
# Higher public record has higher probability of Charge Off the loan.

# %% [markdown]
# <h4>4.2.21. revol_bal

# %% [markdown]
# Total credit revolving balance

# %%
loanData['revol_bal'].sample(5)
# Out:
# 2521     16869.0
# 29880    14246.0
# 6614      9943.0
# 23479     6946.0
# 14391       39.0
# Name: revol_bal, dtype: float64

# %%
loanData['revol_bal'].describe()
# Out:
# count     39441.000000
# mean      12620.627444
# std       16014.590900
# min           0.000000
# 25%        3492.000000
# 50%        8417.000000
# 75%       16113.000000
# max      487589.000000
# Name: revol_bal, dtype: float64

# %%
plot_var('revol_bal','Revolving balance', continuous = True)

# %% [markdown]
# There are too many outliers in this feature, but dropping all of them is bad idea. I'll drop higher than 100000 and log tranform this feature.

# %%
loanData = loanData.drop(loanData[(loanData['revol_bal'] > 100000)].index).reset_index(drop=True)

# %%
loanData.groupby('loan_status')['revol_bal'].describe()
# Out:
#                count          mean           std  min     25%     50%  \
# loan_status
# Charged Off   5951.0  12288.090237  12959.811740  0.0  3688.0  8589.0
# Fully Paid   33300.0  11951.572012  12824.220914  0.0  3437.0  8321.5
#
#                  75%      max
# loan_status
# Charged Off  16413.0  99892.0
# Fully Paid   15864.0  99843.0

# %%
plot_var('revol_bal','Revolving balance', continuous = True)

# %% [markdown]
# Charged Off loans with higher revolving balance have a bit higher mean than Fully Paid.

# %% [markdown]
# <h4>4.2.22. revol_util

# %% [markdown]
# Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
loanData['revol_util'].sample(5)
# Out:
# 20084    88.6%
# 38014    58.8%
# 19580    16.7%
# 17629    65.6%
# 36756    33.7%
# Name: revol_util, dtype: object

# %% [markdown]
# I'll convert is to float and strip "%".

# %%
loanData['revol_util'] = loanData['revol_util'].str.strip('%').astype(float)

# %%
loanData['revol_util'].describe()
# Out:
# count    39251.000000
# mean        48.946548
# std         28.256481
# min          0.000000
# 25%         25.700000
# 50%         49.400000
# 75%         72.300000
# max        119.000000
# Name: revol_util, dtype: float64

# %%
plot_var('revol_util','Revolving line utilization rate', continuous = True)

# %% [markdown]
# Minimum revolving line utilization is 0.0, maximum 119 with mean equal 49.04.

# %%
loanData.groupby('loan_status')['revol_util'].describe()
# Out:
#                count       mean        std  min    25%    50%    75%    max
# loan_status
# Charged Off   5951.0  55.222778  27.932643  0.0  34.15  57.80  78.65  106.5
# Fully Paid   33300.0  47.824932  28.167468  0.0  24.40  47.95  70.90  119.0

# %% [markdown]
# Charge Off status has higher revolving line utilization rate mean, but lower maximum value.

# %% [markdown]
# <h4>4.2.23. total_acc

# %% [markdown]
# The total number of credit lines currently in the borrower's credit file

# %%
loanData['total_acc'].sample(5)
# Out:
# 34113    54.0
# 29267    24.0
# 38993     1.0
# 3953     16.0
# 9036     14.0
# Name: total_acc, dtype: float64

# %%
loanData['total_acc'].describe()
# Out:
# count    39251.000000
# mean        21.403327
# std         11.148960
# min          1.000000
# 25%         13.000000
# 50%         20.000000
# 75%         28.000000
# max         90.000000
# Name: total_acc, dtype: float64

# %%
plot_var('total_acc','Total number of credit lines',continuous = True)

# %% [markdown]
# I'll drop outliers equal or higher than 60.

# %%
loanData = loanData.drop(loanData[(loanData['total_acc']>=60)].index).reset_index(drop=True)

# %%
plot_var('total_acc','Total number of credit lines',continuous = True)

# %%
loanData.groupby('loan_status')['total_acc'].describe()
# Out:
#                count       mean        std  min   25%   50%   75%   max
# loan_status
# Charged Off   5918.0  20.624197  10.939447  1.0  12.0  19.0  28.0  59.0
# Fully Paid   33151.0  21.313475  10.773416  1.0  13.0  20.0  28.0  59.0

# %% [markdown]
# Total number of credit lines in borrowers credit file is higher in loans with Fully Paid status.

# %% [markdown]
# <h4>4.2.24. pub_rec_bankruptcies
#     <a id="4.2.24."></a>

# %% [markdown]
# Number of public record bankruptcies.

# %%
loanData['pub_rec_bankruptcies'].sample(5)
# Out:
# 21398    0.0
# 22789    0.0
# 7637     0.0
# 21125    0.0
# 21       0.0
# Name: pub_rec_bankruptcies, dtype: float64

# %%
loanData['pub_rec_bankruptcies'].describe()
# Out:
# count    39069.000000
# mean         0.045740
# std          0.209778
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          2.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %%
loanData['pub_rec_bankruptcies'].value_counts()
# Out:
# 0.0    37289
# 1.0     1773
# 2.0        7
# Name: pub_rec_bankruptcies, dtype: int64

# %%
plot_var('pub_rec_bankruptcies', 'pub_rec_bankruptcies', continuous = False)

# %%
plot_var('pub_rec_bankruptcies', 'pub_rec_bankruptcies', continuous = True)

# %% [markdown]
# I'll replace 2.0 with 1 and convert it into:<br>   - 0: no public bankrupties;<br> - 1: there were public bankrupties.

# %%
loanData['pub_rec_bankruptcies'] = loanData['pub_rec_bankruptcies'].map({0.0 : 0, 1.0 : 1, 2.0 : 1})

# %%
plot_var('pub_rec_bankruptcies', 'pub_rec_bankruptcies', continuous = False)

# %% [markdown]
# People with with public record bankrupties has higher Charge Off Rate.

# %%
loanData.columns.to_list()
# Out:
# ['loan_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'sub_grade',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'loan_status',
#  'purpose',
#  'dti',
#  'delinq_2yrs',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'pub_rec_bankruptcies',
#  'monthFunded',
#  'region',
#  'earliestYear',
#  'ficoScore',
#  'CreditAge']

# %%
loanData.shape
# Out:
# (39069, 24)

# %% [markdown]
# There are 39440 rows and 24 features.

# %% [markdown]
# <h3> 5. Feature Engineering
#     <a id="5."></a>

# %% [markdown]
# I'll prepare some additional features, they might be usefull to predict loan status.

# %% [markdown]
# <h4> 5.1. percRepay
#     <a id="5.1."></a>

# %% [markdown]
# <b>The percentage of annual income borrower have to repay every year.

# %%
loanData['percRepay'] = (loanData['installment']*12)/loanData['annual_inc']

# %%
loanData['percRepay'].describe()
# Out:
# count    39069.000000
# mean         0.066946
# std          0.039775
# min          0.001890
# 25%          0.036811
# 50%          0.059541
# 75%          0.089419
# max          0.435456
# Name: percRepay, dtype: float64

# %%
plot_var('percRepay','percRepay',continuous = True)

# %% [markdown]
# There are outliers, I'll drop higher than percRepay higher than 0.20%.

# %%
loanData = loanData.drop(loanData[(loanData['percRepay']>0.20)].index).reset_index(drop=True)

# %%
loanData['percRepay'].describe()
# Out:
# count    38876.000000
# mean         0.066152
# std          0.038173
# min          0.001890
# 25%          0.036664
# 50%          0.059344
# 75%          0.088909
# max          0.199993
# Name: percRepay, dtype: float64

# %% [markdown]
# There are 38876 values, minimal value is 0,19%, maximum 20,00%, mean 6,62%

# %%
plot_var('percRepay','percRepay',continuous = True)

# %%
loanData.groupby('loan_status')['percRepay'].describe()
# Out:
#                count      mean       std       min       25%      50%  \
# loan_status
# Charged Off   5873.0  0.072662  0.040453  0.004073  0.040459  0.06630
# Fully Paid   33003.0  0.064993  0.037636  0.001890  0.036062  0.05816
#
#                   75%       max
# loan_status
# Charged Off  0.098634  0.199776
# Fully Paid   0.087269  0.199993

# %% [markdown]
# Borrowers with Charge Off loan status have higher mean and minimum percentage of their annual income to repay loan.

# %%
loanData.describe().T
# Out:
#                         count          mean           std         min  \
# loan_amnt             38876.0  10433.778552   6777.274504   500.00000
# term                  38876.0     42.177796     10.493082    36.00000
# int_rate              38876.0     12.041605      3.633388     5.42000
# installment           38876.0    302.213249    185.500845    15.67000
# annual_inc            38876.0  59915.337901  26930.023464  2000.00000
# dti                   38876.0     13.508868      6.720874     0.00000
# delinq_2yrs           38876.0      0.150247      0.507726     0.00000
# open_acc              38876.0      9.069632      4.173697     1.00000
# pub_rec               38876.0      0.058314      0.234339     0.00000
# revol_bal             38876.0  11979.386614  12827.750509     0.00000
# revol_util            38876.0     49.008650     28.246788     0.00000
# total_acc             38876.0     21.239762     10.797873     1.00000
# ...

# %% [markdown]
# <h4> 5.2. Convert target into 1/0 indicator
#     <a id="5.2."></a>

# %% [markdown]
# I'll convert loan status into integer values: 1 - Fully Paid and 0: Charged Off.

# %%
loanData['loan_status'] = loanData['loan_status'].map({'Fully Paid' : 1, 'Charged Off' : 0})

# %%
loanData['loan_status'].sample(5)
# Out:
# 6665     1
# 8502     1
# 24135    0
# 36303    1
# 5278     1
# Name: loan_status, dtype: int64

# %%
loanData.columns.to_list()
# Out:
# ['loan_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'sub_grade',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'loan_status',
#  'purpose',
#  'dti',
#  'delinq_2yrs',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'pub_rec_bankruptcies',
#  'monthFunded',
#  'region',
#  'earliestYear',
#  'ficoScore',
#  'CreditAge',
#  'percRepay']

# %%
loanData.sample(5)
# Out:
#        loan_amnt  term  int_rate  installment sub_grade emp_length  \
# 35893     9000.0    36     10.39       292.06        B4     0 year
# 30899    24250.0    36     14.96       840.15        D2   10 years
# 17834    12000.0    60     15.28       287.25        D3   10 years
# 27760     5000.0    36     14.59       172.33        D1    8 years
# 9490     16000.0    60     19.69       421.15        E5    7 years
#
#       home_ownership  annual_inc verification_status  loan_status  ...  \
# 35893           RENT     45000.0        Not Verified            1  ...
# 30899       MORTGAGE     67000.0        Not Verified            1  ...
# 17834       MORTGAGE     60000.0        Not Verified            0  ...
# 27760           RENT     58880.0        Not Verified            1  ...
# 9490        MORTGAGE     82000.0        Not Verified            1  ...
#
#       revol_bal  revol_util  total_acc  pub_rec_bankruptcies  monthFunded  \
# ...

# %% [markdown]
# <h4> 5.3. Training Data preparation
#     <a id="5.3."></a>

# %% [markdown]
# Change all white signs with "_"

# %%
loanData = loanData.replace(' ', '_', regex=True)

# %% [markdown]
# Last peek on our data before getting dummies.

# %%
loanData.shape
# Out:
# (38876, 25)

# %% [markdown]
# 38932 rows and 25 features. Let's get dummies now.

# %%
loans = pd.get_dummies(loanData)

# %%
loans.sample(5)
# Out:
#        loan_amnt  term  int_rate  installment  annual_inc  loan_status    dti  \
# 29886    20500.0    36     20.90       771.28     69000.0            0  24.52
# 30594     9250.0    36     12.87       311.11     21996.0            1  15.44
# 11441    12000.0    36     10.99       392.81     39000.0            1  16.55
# 23528    13000.0    60     11.49       285.84     55000.0            1  11.89
# 23659     8000.0    36     13.61       271.91     42000.0            1   7.63
#
#        delinq_2yrs  open_acc  pub_rec  ...  monthFunded_Mar  monthFunded_May  \
# 29886          1.0       6.0        0  ...                0                0
# 30594          0.0      12.0        0  ...                0                0
# 11441          0.0      14.0        0  ...                0                0
# 23528          0.0      12.0        1  ...                0                0
# 23659          0.0       7.0        0  ...                0                0
#
# ...

# %%
loans.isnull().mean().sort_values(ascending=False)
# Out:
# region_West                     0.0
# sub_grade_D5                    0.0
# sub_grade_B5                    0.0
# sub_grade_C1                    0.0
# sub_grade_C2                    0.0
#                                ...
# verification_status_Verified    0.0
# purpose_car                     0.0
# purpose_credit_card             0.0
# purpose_debt_consolidation      0.0
# loan_amnt                       0.0
# Length: 102, dtype: float64

# %%
loans.shape
# Out:
# (38876, 102)

# %% [markdown]
# There are 39233 rows and 102 features without NaN values.

# %% [markdown]
# I decided to use less columns. I'll overwrite "loans" Data Frame

# %%
loans = loans[['loan_amnt', 'term', 'int_rate', 'installment', 'annual_inc', 'dti', 'delinq_2yrs',
               'open_acc', 'total_acc', 'pub_rec_bankruptcies', 'earliestYear',
               'ficoScore', 'CreditAge','revol_bal','revol_util', 'percRepay',
               'region_MidWest', 'region_NorthEast', 'region_SouthEast', 'region_SouthWest','region_West',
               'pub_rec', 'loan_status']]

# %%
loans.shape
# Out:
# (38876, 23)

# %% [markdown]
# The Data Frame have 38876 rows and 23 features.

# %% [markdown]
# <h2> 6. Prepare Data for Model Training and Testing
#     <a id="6."></a>

# %% [markdown]
# Preparing the data frame

# %%
from imblearn.over_sampling import SMOTEN
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Prepare sampled Data Frame.

# %%
loansSampled = loans.sample(1000)

# %% [markdown]
# Divide our Data Set for 2 variables X for all features without target and y for target.

# %%
X = loans.drop(['loan_status'], axis=1)
y = loans['loan_status']

# %%
Xs = loansSampled.drop(['loan_status'], axis=1)
ys = loansSampled['loan_status']

# %% [markdown]
# <h4> 6.1. Dealing with unbalanced class samples.
#     <a id="6.1."></a>

# %%
loans.shape
# Out:
# (38876, 23)

# %% [markdown]
# There is 38876 rows before oversampling.

# %%
sampler = SMOTEN(random_state=2137)
X_res, y_res = sampler.fit_resample(X, y)
X_res[y.size:]
y_res[y.size:]
# Out:
# 38876    0
# 38877    0
# 38878    0
# 38879    0
# 38880    0
#         ..
# 66001    0
# 66002    0
# 66003    0
# 66004    0
# 66005    0
# Name: loan_status, Length: 27130, dtype: int64

# %%
X_res.shape
# Out:
# (66006, 22)

# %% [markdown]
# There is 66006 rows after oversampling. Let's prepare our new Data Frame.

# %%
loans = X_res.copy()

# %%
loans['loan_status'] = y_res.copy()

# %%
loansPCA = loans.copy()

# %%
loans.sample(5)
# Out:
#        loan_amnt  term  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 29428    18000.0    36     14.59       620.37     56000.0  12.39          0.0
# 45691     3600.0    36      7.49       111.97     27500.0   5.76          0.0
# 14086    13500.0    60      9.99       286.77     60000.0   9.24          0.0
# 7693      4000.0    36      5.99       121.67     50582.0   4.29          0.0
# 52163     2400.0    36      9.76        57.83     16008.0   6.74          0.0
#
#        open_acc  total_acc  pub_rec_bankruptcies  ...  revol_bal  revol_util  \
# 29428       4.0       19.0                     0  ...    11300.0        90.2
# 45691       6.0       10.0                     0  ...     1683.0        40.2
# 14086      13.0       35.0                     0  ...     8741.0        11.0
# 7693        9.0       15.0                     0  ...     4533.0        33.1
# 52163       3.0        8.0                     0  ...      807.0        23.1
#
# ...

# %%
X = X_res
y = y_res

# %%
loans.shape
# Out:
# (66006, 23)

# %%
X.shape
# Out:
# (66006, 22)

# %% [markdown]
# <h4>6.2. Standarization of the features
#     <a id="6.2."></a>

# %% [markdown]
# Standarization of "loans" Data Frame

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(X_scaled,columns=X.columns)

# %%
scaler = StandardScaler()
sampledX_scaled = scaler.fit_transform(Xs)

# %%
sampledX_scaled_df = pd.DataFrame(sampledX_scaled,columns=Xs.columns)

# %%
X_scaled_df.shape
# Out:
# (66006, 22)

# %%
sampledX_scaled_df.shape
# Out:
# (1000, 22)

# %% [markdown]
# <h3> 7. Clustering
#     <a id="7."></a>

# %% [markdown]
# I'll use:<ol> <li>KMeans, <li>Hierarchical Clustering, <li>DBSCAN.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree
from sklearn import datasets
from sklearn.cluster import DBSCAN

# %% [markdown]
# <h4> 7.1. K-Means Clustering
#     <a id="7.1."></a>

# %% [markdown]
# Let's find the best number of clusters.

# %%
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=1000, random_state = 2137)
    kmeans.fit(X_scaled)
    
    ssd.append(kmeans.inertia_)

plt.plot(ssd)

# %% [markdown]
# It looks that using 2 clusters is a good idea. Let's check Silhoette score.

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=1000, random_state = 2137)
    kmeans.fit(X_scaled)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(X_scaled_df, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.16738895220164263
# For n_clusters=3, the silhouette score is 0.13274420668109652
# For n_clusters=4, the silhouette score is 0.15172862867996742
# For n_clusters=5, the silhouette score is 0.16100216861133523
# For n_clusters=6, the silhouette score is 0.1459357843471377
# For n_clusters=7, the silhouette score is 0.15532884978388242
# For n_clusters=8, the silhouette score is 0.17395243956686995

# %% [markdown]
# 2 and 3 clusters looks good. I decided to use 2 clusters, because I can chceck differences between KMeans and our target.

# %%
kmeans = KMeans(n_clusters=2, max_iter=1000, random_state=2137)
kmeans.fit(X_scaled)
# Out:
# KMeans(max_iter=1000, n_clusters=2, random_state=2137)

# %%
kmeans.labels_
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# Save labels into new features.

# %%
loans['K-Means_Cluster_ID'] = kmeans.labels_

# %% [markdown]
# Let's recall the distribution of loan statuses.

# %%
loans['loan_status'].value_counts()
# Out:
# 1    33003
# 0    33003
# Name: loan_status, dtype: int64

# %% [markdown]
# Loan status is balanced. Let's see the distribution of K-Means Cluster labels.

# %%
loans['K-Means_Cluster_ID'].value_counts()
# Out:
# 1    39890
# 0    26116
# Name: K-Means_Cluster_ID, dtype: int64

# %% [markdown]
# K-Means Cluster is more unbalanced. Let's visualize it with 5 features.

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(5,2,1)
sns.boxplot(x='K-Means_Cluster_ID', y='loan_amnt', data=loans)

plt.subplot(5,2,2)
sns.boxplot(x='loan_status', y='loan_amnt', data=loans)

plt.subplot(5,2,3)
sns.boxplot(x='K-Means_Cluster_ID', y='int_rate', data=loans)

plt.subplot(5,2,4)
sns.boxplot(x='loan_status', y='int_rate', data=loans)

plt.subplot(5,2,5)
sns.boxplot(x='K-Means_Cluster_ID', y='installment', data=loans)

plt.subplot(5,2,6)
sns.boxplot(x='loan_status', y='installment', data=loans)

plt.subplot(5,2,7)
sns.boxplot(x='K-Means_Cluster_ID', y='annual_inc', data=loans)

plt.subplot(5,2,8)
sns.boxplot(x='loan_status', y='annual_inc', data=loans)

plt.subplot(5,2,9)
sns.boxplot(x='K-Means_Cluster_ID', y='percRepay', data=loans)

plt.subplot(5,2,10)
sns.boxplot(x='loan_status', y='percRepay', data=loans)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='percRepay'>

# %% [markdown]
# Both distributions looks similar. Cluster "0" in K-Means Cluster probably is Fully Paid loan status converted into "1".

# %% [markdown]
# <h4> 7.2. Hierarchical Clustering
#     <a id="7.2."></a>

# %% [markdown]
# I'll use complete method with euclidean metric.

# %%
cl_mergings = linkage(X_scaled, method="complete", metric='euclidean')

# %%
sampled_cl_mergings = linkage(sampledX_scaled, method="complete", metric='euclidean')

# %% [markdown]
# I can visualize loanSampled Data Frame only.

# %%
dendrogram(sampled_cl_mergings)
# Out:
# {'icoord': [[35.0, 35.0, 45.0, 45.0],
#   [25.0, 25.0, 40.0, 40.0],
#   [15.0, 15.0, 32.5, 32.5],
#   [55.0, 55.0, 65.0, 65.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [60.0, 60.0, 80.0, 80.0],
#   [23.75, 23.75, 70.0, 70.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [115.0, 115.0, 125.0, 125.0],
#   [100.0, 100.0, 120.0, 120.0],
#   [145.0, 145.0, 155.0, 155.0],
#   [135.0, 135.0, 150.0, 150.0],
#   [110.0, 110.0, 142.5, 142.5],
#   [46.875, 46.875, 126.25, 126.25],
#   [185.0, 185.0, 195.0, 195.0],
#   [175.0, 175.0, 190.0, 190.0],
#   [165.0, 165.0, 182.5, 182.5],
#   [215.0, 215.0, 225.0, 225.0],
#   [205.0, 205.0, 220.0, 220.0],
#   [235.0, 235.0, 245.0, 245.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [275.0, 275.0, 290.0, 290.0],
#   [265.0, 265.0, 282.5, 282.5],
#   [255.0, 255.0, 273.75, 273.75],
#   [240.0, 240.0, 264.375, 264.375],
#   [212.5, 212.5, 252.1875, 252.1875],
#   [305.0, 305.0, 315.0, 315.0],
#   [335.0, 335.0, 345.0, 345.0],
#   [325.0, 325.0, 340.0, 340.0],
# ...

# %% [markdown]
# Dendrogram shows that 2 clusters are good.

# %%
cl_cluster_labels = cut_tree(cl_mergings, n_clusters=2).reshape(-1, )
cl_cluster_labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# Save labels into Data Frames

# %%
loans["Hierarchical_Cluster_labels"] = cl_cluster_labels
loans["Hierarchical_Cluster_labels"].sample(10)
# Out:
# 48779    0
# 61722    0
# 39360    0
# 14558    0
# 48488    0
# 5738     0
# 5971     0
# 60233    0
# 49663    0
# 35639    0
# Name: Hierarchical_Cluster_labels, dtype: int32

# %%
loans.to_csv("loansHierarchical.csv", index=False, header=False)

# %% [markdown]
# Visualization Hierarchical Cluster labels and target.

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(5,2,1)
sns.boxplot(x='Hierarchical_Cluster_labels', y='loan_amnt', data=loans)

plt.subplot(5,2,2)
sns.boxplot(x='loan_status', y='loan_amnt', data=loans)

plt.subplot(5,2,3)
sns.boxplot(x='Hierarchical_Cluster_labels', y='int_rate', data=loans)

plt.subplot(5,2,4)
sns.boxplot(x='loan_status', y='int_rate', data=loans)

plt.subplot(5,2,5)
sns.boxplot(x='Hierarchical_Cluster_labels', y='installment', data=loans)

plt.subplot(5,2,6)
sns.boxplot(x='loan_status', y='installment', data=loans)

plt.subplot(5,2,7)
sns.boxplot(x='Hierarchical_Cluster_labels', y='annual_inc', data=loans)

plt.subplot(5,2,8)
sns.boxplot(x='loan_status', y='annual_inc', data=loans)

plt.subplot(5,2,9)
sns.boxplot(x='Hierarchical_Cluster_labels', y='percRepay', data=loans)

plt.subplot(5,2,10)
sns.boxplot(x='loan_status', y='percRepay', data=loans)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='percRepay'>

# %% [markdown]
# Hierarchical Cluster labels are more balanced than target.

# %% [markdown]
# Visualization Hierarchical Clustering labels, target and KMeans Clustering labels.

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(5,3,1)
sns.boxplot(x='Hierarchical_Cluster_labels', y='loan_amnt', data=loans)

plt.subplot(5,3,2)
sns.boxplot(x='loan_status', y='loan_amnt', data=loans)

plt.subplot(5,3,3)
sns.boxplot(x='K-Means_Cluster_ID', y='loan_amnt', data=loans)

plt.subplot(5,3,4)
sns.boxplot(x='Hierarchical_Cluster_labels', y='int_rate', data=loans)

plt.subplot(5,3,5)
sns.boxplot(x='loan_status', y='int_rate', data=loans)

plt.subplot(5,3,6)
sns.boxplot(x='K-Means_Cluster_ID', y='int_rate', data=loans)

plt.subplot(5,3,7)
sns.boxplot(x='Hierarchical_Cluster_labels', y='installment', data=loans)

plt.subplot(5,3,8)
sns.boxplot(x='loan_status', y='installment', data=loans)

plt.subplot(5,3,9)
sns.boxplot(x='K-Means_Cluster_ID', y='installment', data=loans)

plt.subplot(5,3,10)
sns.boxplot(x='Hierarchical_Cluster_labels', y='annual_inc', data=loans)

plt.subplot(5,3,11)
sns.boxplot(x='loan_status', y='annual_inc', data=loans)

plt.subplot(5,3,12)
sns.boxplot(x='K-Means_Cluster_ID', y='annual_inc', data=loans)

plt.subplot(5,3,13)
sns.boxplot(x='Hierarchical_Cluster_labels', y='percRepay', data=loans)

plt.subplot(5,3,14)
sns.boxplot(x='loan_status', y='percRepay', data=loans)

plt.subplot(5,3,15)
sns.boxplot(x='K-Means_Cluster_ID', y='percRepay', data=loans)
# Out:
# <AxesSubplot:xlabel='K-Means_Cluster_ID', ylabel='percRepay'>

# %% [markdown]
# There are more similarities of target with K-Means Cluster than Hierarchical Cluster

# %% [markdown]
# <h4> 7.3. DBSCAN
#     <a id="7.3."></a>

# %% [markdown]
# Default epsilon was too low, almost all labels were classified as noise. I decided to increase epsilon to 5 and minimum samples to 10.

# %%
dbscan = DBSCAN(eps=5 , metric='euclidean', min_samples=10, n_jobs=-1)
model = dbscan.fit(X_scaled)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(X_scaled)
pca_2d = pca.transform(X_scaled)
for i in range(0, pca_2d.shape[0]):
    if dbscan.labels_[i] == 0:
        c1 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='r', marker='+')
    elif dbscan.labels_[i] == 1:
        c2 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='g', marker='o')
    elif dbscan.labels_[i] == -1:
            c3 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='b', marker='*')
plt.legend([c1, c2, c3], ['Cluster 1', 'Cluster 2', 'Noise'])
plt.title('DBSCAN finds 2 clusters and noise')
plt.show()

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
loans['DBSCAN']=dbscan.labels_

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(5,1,1)
sns.boxplot(x='DBSCAN', y='loan_amnt', data=loans)

plt.subplot(5,1,2)
sns.boxplot(x='DBSCAN', y='int_rate', data=loans)

plt.subplot(5,1,3)
sns.boxplot(x='DBSCAN', y='installment', data=loans)

plt.subplot(5,1,4)
sns.boxplot(x='DBSCAN', y='annual_inc', data=loans)

plt.subplot(5,1,5)
sns.boxplot(x='DBSCAN', y='percRepay', data=loans)
# Out:
# <AxesSubplot:xlabel='DBSCAN', ylabel='percRepay'>

# %% [markdown]
# There is diversity in DBSCAN Clustering, in 3/5 presented features "0" and "1" dominates, but installment and annual income have tendency to be assigned to the noise.

# %% [markdown]
# <h3> 8. Model training
#     <a id="8."></a>

# %% [markdown]
# <h4> b) Wytrenuj 5 różnych modeli,wykorzystując do każdego inny algorytm, a następnie porównaj ich działanie, za metrykę oceny jakości modelu przyjmij AUROC score.(50pkt)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report,confusion_matrix
import matplotlib as mpl
from cycler import cycler
import xgboost as xgb
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

# %% [markdown]
# Split our Data Frame into train and test samples.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=2137)

# %%
X_train.shape
# Out:
# (46204, 22)

# %% [markdown]
# Prepare function for:<ol>
#     <li> prediction f1-score and accuracy of the model
#     <li> visualization learning curve of the model

# %%
def evaluate(prediction,y_test): 
    result = classification_report(y_test,prediction,output_dict=True)
    f1 = result['1']['f1-score']
    accuracy = result['accuracy']
    performance_data= {'f1-score':round(f1, 2),
                      'accuracy':round(accuracy, 2)}
    return performance_data

# %%
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

def plot_learning_curve(estimator, title, X_scaled, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X_scaled, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# <h4> 8.1. Logistic Regression
#     <a id="8.1."></a>

# %%
current_model = 'Logistic Regression'
learning_model = "Learning Curve for " + current_model 
model = LogisticRegression(max_iter = 1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lr_pred = model.predict(X_test)

# %%
lr_prediction = model.predict_proba(X_test)[:, 1]

# %% [markdown]
# <h5> 8.1.1. Visualization ROC Curve
#     <a id="8.1.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(y_test, lr_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Logistic Regression')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
lr_auc = roc_auc_score(y_test, lr_prediction)
print('ROC AUC : {:.4f}'.format(lr_auc))
plt.show()
# Out:
# ROC AUC : 0.9308

# %%
confusion_matrix(y_test, lr_pred)
# Out:
# array([[7984, 1884],
#        [ 222, 9712]], dtype=int64)

# %% [markdown]
# <h5> 8.1.2. Visualization Learning Curve
#     <a id="8.1.2."></a>

# %%
plot_learning_curve(model, learning_model, X_scaled, y, (0.7, 1.01), cv=cv, n_jobs=4),
plt.show()

# %% [markdown]
# Training score and cross-validation score overlap in this model. Model is well trained.

# %%
print(classification_report(y_test,lr_pred))

dtree_pr= evaluate(lr_pred,y_test)
dtree_pr
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88      9868
#            1       0.84      0.98      0.90      9934
#
#     accuracy                           0.89     19802
#    macro avg       0.91      0.89      0.89     19802
# weighted avg       0.91      0.89      0.89     19802
# {'f1-score': 0.9, 'accuracy': 0.89}

# %%
evaluate(y_test, lr_pred)
# Out:
# {'f1-score': 0.9, 'accuracy': 0.89}

# %% [markdown]
# <h5> 8.1.3. Model Summary
#     <a id="8.1.3."></a>

# %%
model_summary = evaluate(y_test, lr_pred)
model_summary['model'] = current_model
model_summary['auroc'] = lr_auc
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                model     auroc
# 0       0.9      0.89  Logistic Regression  0.930768

# %% [markdown]
# This model has 0,93 ROC AUC score.

# %% [markdown]
# <h4> 8.2. Decision Tree
#     <a id="8.2."></a>

# %%
current_model = 'Decision Tree'
learning_model = "Learning Curve for " + current_model 
model = DecisionTreeClassifier(max_depth=13)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=13)

# %%
dt_prediction = model.predict(X_test)

# %% [markdown]
# <h4>Visualization of Decision Tree

# %%
tree.plot_tree(model)
# Out:
# [Text(163.3669226520097, 209.6742857142857, 'X[3] <= -0.298\ngini = 0.5\nsamples = 46204\nvalue = [23135, 23069]'),
#  Text(95.21726795144492, 194.14285714285714, 'X[5] <= 0.388\ngini = 0.419\nsamples = 23408\nvalue = [16420, 6988]'),
#  Text(57.79084733020391, 178.61142857142858, 'X[11] <= 1.154\ngini = 0.32\nsamples = 18489\nvalue = [14787, 3702]'),
#  Text(40.172500733460474, 163.07999999999998, 'X[14] <= 0.978\ngini = 0.27\nsamples = 16939\nvalue = [14220, 2719]'),
#  Text(30.09369223998827, 147.54857142857142, 'X[16] <= 1.456\ngini = 0.219\nsamples = 15415\nvalue = [13490, 1925]'),
#  Text(23.003073199354557, 132.01714285714286, 'X[6] <= 1.013\ngini = 0.194\nsamples = 15022\nvalue = [13390, 1632]'),
#  Text(16.305354261405313, 116.48571428571428, 'X[19] <= 1.852\ngini = 0.165\nsamples = 14490\nvalue = [13174, 1316]'),
#  Text(9.503271233680506, 100.9542857142857, 'X[17] <= 0.843\ngini = 0.149\nsamples = 14308\nvalue = [13144, 1164]'),
# ...

# %% [markdown]
# <h5> 8.2.1. Visualization of ROC Curve
#     <a id="8.2.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(y_test, dt_prediction)
plt.figure(figsize=(10,5))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Decision Tree classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
dt_auc = roc_auc_score(y_test, dt_prediction)
print('ROC AUC : {:.4f}'.format(dt_auc))
plt.show()
# Out:
# ROC AUC : 0.8715

# %%
confusion_matrix(y_test, dt_prediction)
# Out:
# array([[8191, 1677],
#        [ 865, 9069]], dtype=int64)

# %% [markdown]
# <h5> 8.2.2. Visualization of Learning Curve
#     <a id="8.2.2."></a>

# %%
plot_learning_curve(model, learning_model, X_scaled, y, (0.7, 1.01), cv=cv, n_jobs=4),
plt.show()

# %% [markdown]
# Both curves are covergent, but there is a big gap between them.

# %%
print(classification_report(y_test,dt_prediction))

dtree_pr= evaluate(dt_prediction,y_test)
dtree_pr
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.87      9868
#            1       0.84      0.91      0.88      9934
#
#     accuracy                           0.87     19802
#    macro avg       0.87      0.87      0.87     19802
# weighted avg       0.87      0.87      0.87     19802
# {'f1-score': 0.88, 'accuracy': 0.87}

# %% [markdown]
# <h5> 8.2.3. Model Summary
#     <a id="8.2.3."></a>

# %%
model_summary = evaluate(y_test, dt_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = dt_auc
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy          model     auroc
# 0      0.88      0.87  Decision Tree  0.871491

# %% [markdown]
# This model has 0,87 ROC AUC score, it's not as good as Logistic Regression model.

# %% [markdown]
# <h4> 8.2. Random Forest
#     <a id="8.2."></a>

# %%
current_model = 'Random Forest Classifier'
learning_model = "Learning Curve for " + current_model 
model = RandomForestClassifier(n_estimators=50)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
rf_prediction = model.predict(X_test)

# %% [markdown]
# <h5> 8.3.1. Visualization of ROC Curve
#     <a id="8.3.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(y_test, rf_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Rain Forest classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
rf_auc = roc_auc_score(y_test, rf_prediction)
print('ROC AUC : {:.4f}'.format(rf_auc))
plt.show()
# Out:
# ROC AUC : 0.9056

# %%
confusion_matrix(y_test, rf_prediction)
# Out:
# array([[8162, 1706],
#        [ 158, 9776]], dtype=int64)

# %% [markdown]
# <h5> 8.3.2. Visualization of Learning Curve
#     <a id="8.3.2."></a>

# %%
plot_learning_curve(model, learning_model, X_scaled, y, (0.7, 1.01), cv=cv, n_jobs=4),
plt.show()

# %%
print(classification_report(y_test,rf_prediction))
rf_pr = evaluate(rf_prediction,y_test)
print(rf_pr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90      9868
#            1       0.85      0.98      0.91      9934
#
#     accuracy                           0.91     19802
#    macro avg       0.92      0.91      0.91     19802
# weighted avg       0.92      0.91      0.91     19802
#
# {'f1-score': 0.91, 'accuracy': 0.91}

# %% [markdown]
# <h5> 8.3.3. Model Summary
#     <a id="8.3.3."></a>

# %%
model_summary = evaluate(y_test, rf_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = rf_auc
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                     model     auroc
# 0      0.91      0.91  Random Forest Classifier  0.905606

# %% [markdown]
# <h4> 8.4. SVM
#     <a id="8.4."></a>

# %%
current_model = 'SVM'
model = SVC(C = 0.1)
model.fit(X_train,y_train)
# Out:
# SVC(C=0.1)

# %%
svm_prediction = model.predict(X_test)

# %% [markdown]
# <h5> 8.4.1. Visualization of ROC Curve
#     <a id="8.4.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(y_test, svm_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a SVM classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
svm_auc = roc_auc_score(y_test, svm_prediction)
print('ROC AUC : {:.4f}'.format(svm_auc))
plt.show()
# Out:
# ROC AUC : 0.8995

# %%
confusion_matrix(y_test, svm_prediction)
# Out:
# array([[7927, 1941],
#        [  43, 9891]], dtype=int64)

# %%
print(classification_report(y_test,svm_prediction))
svm_pr = evaluate(svm_prediction,y_test)
svm_pr
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.89      9868
#            1       0.84      1.00      0.91      9934
#
#     accuracy                           0.90     19802
#    macro avg       0.92      0.90      0.90     19802
# weighted avg       0.92      0.90      0.90     19802
# {'f1-score': 0.91, 'accuracy': 0.9}

# %% [markdown]
# <h5> 8.4.2. Model Summary
#     <a id="8.4.2."></a>

# %%
model_summary = evaluate(y_test, svm_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = svm_auc
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy model     auroc
# 0      0.91       0.9   SVM  0.899488

# %% [markdown]
# This model has ~0,90 ROC AUC score.

# %% [markdown]
# <h4> 8.5. K Nearest Neighbors Classifier (KNN
#     <a id="8.5."></a>

# %%
current_model = 'K Nearest Neighbors Classifier'
learning_model = "Learning Curve for " + current_model 
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_prediction = model.predict(X_test)

# %% [markdown]
# <h5> 8.5.1. Visualization of ROC Curve
#     <a id="8.5.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(y_test, knn_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a K Nearest Neighbors Classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
knn_auc = roc_auc_score(y_test, knn_prediction)
print('ROC AUC : {:.4f}'.format(knn_auc))
plt.show()
# Out:
# ROC AUC : 0.8910

# %%
confusion_matrix(y_test, knn_prediction)
# Out:
# array([[8183, 1685],
#        [ 469, 9465]], dtype=int64)

# %%
print(classification_report(knn_prediction,y_test))
knn1_pr = evaluate(knn_prediction,y_test)
knn1_pr
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88      8652
#            1       0.95      0.85      0.90     11150
#
#     accuracy                           0.89     19802
#    macro avg       0.89      0.90      0.89     19802
# weighted avg       0.90      0.89      0.89     19802
# {'f1-score': 0.9, 'accuracy': 0.89}

# %% [markdown]
# <h5> 8.5.2. Model Summary
#     <a id="8.5.2."></a>

# %%
model_summary = evaluate(y_test, knn_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = knn_auc
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                           model     auroc
# 0       0.9      0.89  K Nearest Neighbors Classifier  0.891017

# %% [markdown]
# This model has 0,89 ROC AUC score.

# %% [markdown]
# <h3> 9. Model Training Summary
#     <a id="9."></a>

# %%
prediction_data={'Model':['Logistic Regression',
                          'Decision Tree',
                          'Random Forest',
                          'SVM',
                          'KNN'
                         ],
                    'ROC AUC':[lr_auc,
                              dt_auc, 
                              rf_auc,
                              svm_auc,
                              knn_auc]
                    }
 
# Create DataFrame
prediction_table = pd.DataFrame(prediction_data)
prediction_table
# Out:
#                  Model   ROC AUC
# 0  Logistic Regression  0.930768
# 1        Decision Tree  0.871491
# 2        Random Forest  0.905606
# 3                  SVM  0.899488
# 4                  KNN  0.891017

# %% [markdown]
# The best model for our Data Frame without PCA is Logistic Regression, the worst is Decision Tree classifier (0,87 ROC AUC score).

# %% [markdown]
# <b><u>b) Wytrenuj 5 różnych modeli,wykorzystując do każdego inny algorytm, a następnie porównaj ich działanie, za metrykę oceny jakości modelu przyjmij AUROC score.(50pkt)

# %% [markdown]
# The best of trained models is Logistic Regression 94,55 ROC AUC Score, the worst is KNN and Decision Tree.

# %% [markdown]
# <h3> 10. PCA
#     <a id="10."></a>

# %% [markdown]
# c) Sprawdź działanie wcześniej użytych metod na skompresowanych danych za pomocą PCA, porównaj wyniki (AUROC score) z modelami wytrenowanymi w poprzednim podpunkcie. (20pkt)

# %% [markdown]
# <h4> 10.1. Preparing PCA decomposition
#     <a id="10.1."></a>

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA

# %%
pca = PCA(random_state=2137)
pca.fit(X_scaled)
# Out:
# PCA(random_state=2137)

# %%
pca.components_[0]
# Out:
# array([ 0.33367   ,  0.06721094,  0.09357408,  0.38959081,  0.31772214,
#         0.28368801,  0.05801341,  0.26998134,  0.32762018,  0.02474091,
#        -0.08988998,  0.1336281 ,  0.2711459 ,  0.33240813,  0.20619153,
#         0.27061281,  0.08459857,  0.08699053,  0.08132432,  0.07506716,
#         0.06916764,  0.0229292 ])

# %%
var_cumu = np.cumsum(pca.explained_variance_ratio_)
var_cumu
# Out:
# array([0.1944499 , 0.29660048, 0.38674596, 0.45504653, 0.52085929,
#        0.57684211, 0.63140723, 0.68248977, 0.73138836, 0.77862332,
#        0.82375116, 0.86311318, 0.89608133, 0.91807323, 0.93611822,
#        0.95167696, 0.96635012, 0.97735424, 0.98493028, 0.99141237,
#        0.99627256, 1.        ])

# %% [markdown]
# <h4> 10.1.1. Finding number of components for Final PCA decomposition
#     <a id="10.1.1."></a>

# %% [markdown]
# I decided to search number of component which will explain 90% of variance.

# %%
fig = plt.figure(figsize=[10,4],dpi=200)
plt.vlines(x=12, ymax=1, ymin=0, colors="r", linestyles="--")
plt.hlines(y=0.90, xmax=80, xmin=0, colors="g", linestyles="--")
plt.plot(var_cumu)
plt.ylabel("Cumulative variance explained")
plt.show()

# %% [markdown]
# 90% of cumulative variance will be explained with 12 components

# %%
pca_final = IncrementalPCA(n_components=12)
X_pca_final = pca_final.fit_transform(X_scaled)

# %%
print(X.shape)
print(X_pca_final.shape)
# Out:
# (66006, 22)
# (66006, 12)

# %%
colnames = list(X.columns)
pca_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1], 'Feature':colnames})
pca_df.head()
# Out:
#         PC1       PC2      Feature
# 0  0.333670 -0.110708    loan_amnt
# 1  0.067211 -0.195004         term
# 2  0.093574 -0.543789     int_rate
# 3  0.389591 -0.104370  installment
# 4  0.317722  0.085983   annual_inc

# %%
pca_df
# Out:
#          PC1       PC2               Feature
# 0   0.333670 -0.110708             loan_amnt
# 1   0.067211 -0.195004                  term
# 2   0.093574 -0.543789              int_rate
# 3   0.389591 -0.104370           installment
# 4   0.317722  0.085983            annual_inc
# 5   0.283688 -0.082703                   dti
# 6   0.058013 -0.059012           delinq_2yrs
# 7   0.269981  0.135772              open_acc
# 8   0.327620  0.195468             total_acc
# 9   0.024741 -0.170134  pub_rec_bankruptcies
# 10 -0.089890 -0.275127          earliestYear
# 11  0.133628  0.462777             ficoScore
# 12  0.271146  0.266684             CreditAge
# 13  0.332408  0.002896             revol_bal
# 14  0.206192 -0.346723            revol_util
# 15  0.270613 -0.155133             percRepay
# 16  0.084599  0.003547        region_MidWest
# 17  0.086991  0.011516      region_NorthEast
# 18  0.081324  0.030119      region_SouthEast
# 19  0.075067  0.017840      region_SouthWest
# ...

# %% [markdown]
# <h4> 10.1.2. Visualisation of principal components.
#     <a id="10.1.2."></a>

# %%
fig = plt.figure(figsize = (12,6))
plt.scatter(pca_df.PC1, pca_df.PC2)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
for i, txt in enumerate(pca_df.Feature):
    plt.annotate(txt, (pca_df.PC1[i],pca_df.PC2[i]))
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4> 10.2. Define functions
#     <a id="10.2."></a>

# %% [markdown]
# Define function for:<ol>
#     <li> prediction f1-score and accuracy of the model
#     <li> visualization learning curve of the model

# %%
def evaluatePCA(prediction,yp_test): 
    result = classification_report(yp_test,prediction,output_dict=True)
    f1 = result['1']['f1-score']
    accuracy = result['accuracy']
    performance_dataPCA= {'f1-score':round(f1, 2),
                      'accuracy':round(accuracy, 2)}
    return performance_dataPCA

# %%
def plot_learning_curvePCA(estimator, title, X_pca_final, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X_pca_final, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# <h3> 11. Clustering
#     <a id="11."></a>

# %% [markdown]
# I decided to use KMeans Clustering and compare it with target and non PCA KMeans Clustering.

# %% [markdown]
# <h4>11.1. KMeans(PCA)
#     <a id="11.1."></a>

# %% [markdown]
# I'll use the same number of clusters like non PCA KMeans Clustering.

# %%
kmeansPCA = KMeans(n_clusters=2, max_iter=1000, random_state=2137)
kmeansPCA.fit(X_pca_final)
# Out:
# KMeans(max_iter=1000, n_clusters=2, random_state=2137)

# %%
kmeansPCA.labels_
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
loansPCA['K-Means_Cluster_ID_pca'] = kmeansPCA.labels_

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(5,2,1)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='loan_amnt', data=loansPCA)

plt.subplot(5,2,2)
sns.boxplot(x='loan_status', y='loan_amnt', data=loansPCA)

plt.subplot(5,2,3)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='int_rate', data=loansPCA)

plt.subplot(5,2,4)
sns.boxplot(x='loan_status', y='int_rate', data=loansPCA)

plt.subplot(5,2,5)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='installment', data=loansPCA)

plt.subplot(5,2,6)
sns.boxplot(x='loan_status', y='installment', data=loansPCA)

plt.subplot(5,2,7)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='annual_inc', data=loansPCA)

plt.subplot(5,2,8)
sns.boxplot(x='loan_status', y='annual_inc', data=loansPCA)

plt.subplot(5,2,9)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='percRepay', data=loansPCA)

plt.subplot(5,2,10)
sns.boxplot(x='loan_status', y='percRepay', data=loansPCA)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='percRepay'>

# %%
plt.figure(figsize=(20,20), dpi=200)

plt.subplot(5,2,1)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='loan_amnt', data=loansPCA)

plt.subplot(5,2,2)
sns.boxplot(x='K-Means_Cluster_ID', y='loan_amnt', data=loans)

plt.subplot(5,2,3)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='int_rate', data=loansPCA)

plt.subplot(5,2,4)
sns.boxplot(x='K-Means_Cluster_ID', y='int_rate', data=loans)

plt.subplot(5,2,5)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='installment', data=loansPCA)

plt.subplot(5,2,6)
sns.boxplot(x='K-Means_Cluster_ID', y='installment', data=loans)

plt.subplot(5,2,7)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='annual_inc', data=loansPCA)

plt.subplot(5,2,8)
sns.boxplot(x='K-Means_Cluster_ID', y='annual_inc', data=loans)

plt.subplot(5,2,9)
sns.boxplot(x='K-Means_Cluster_ID_pca', y='percRepay', data=loansPCA)

plt.subplot(5,2,10)
sns.boxplot(x='K-Means_Cluster_ID', y='percRepay', data=loans)
# Out:
# <AxesSubplot:xlabel='K-Means_Cluster_ID', ylabel='percRepay'>

# %% [markdown]
# I can't see any difference between non PCA and PCA K-Means Cluster. In PCA version "1" is "0" of non PCA cluster. I'll do t-student tests to confirm or this.

# %% [markdown]
# H0: the means of the samples are equal.<br>
# H1: the means of the samples are unequal.

# %% [markdown]
# loan_amnt

# %%
from scipy.stats import ttest_ind
data1 = loansPCA[loansPCA['K-Means_Cluster_ID_pca'] == 1]['loan_amnt']
data2 = loans[loans['K-Means_Cluster_ID'] == 0]['loan_amnt']
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=2.335, p=0.020
# Probably different distributions

# %% [markdown]
# int_rate

# %%
from scipy.stats import ttest_ind
data1 = loansPCA[loansPCA['K-Means_Cluster_ID_pca'] == 1]['int_rate']
data2 = loans[loans['K-Means_Cluster_ID'] == 0]['int_rate']
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=0.863, p=0.388
# Probably the same distribution

# %% [markdown]
# installment

# %%
from scipy.stats import ttest_ind
data1 = loansPCA[loansPCA['K-Means_Cluster_ID_pca'] == 1]['installment']
data2 = loans[loans['K-Means_Cluster_ID'] == 0]['installment']
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=2.245, p=0.025
# Probably different distributions

# %% [markdown]
# annual_inc

# %%
from scipy.stats import ttest_ind
data1 = loansPCA[loansPCA['K-Means_Cluster_ID_pca'] == 1]['annual_inc']
data2 = loans[loans['K-Means_Cluster_ID'] == 0]['annual_inc']
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=1.098, p=0.272
# Probably the same distribution

# %% [markdown]
# percRepay

# %%
from scipy.stats import ttest_ind
data1 = loansPCA[loansPCA['K-Means_Cluster_ID_pca'] == 1]['percRepay']
data2 = loans[loans['K-Means_Cluster_ID'] == 0]['percRepay']
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=1.122, p=0.262
# Probably the same distribution

# %% [markdown]
# There are differences in some features. I visualized 5 features, 3 of them loan_amnt and installment mean are unequal.

# %% [markdown]
# <h3> 12. Model Training (PCA)
#     <a id="12."></a>

# %%
Xp_train, Xp_test, yp_train, yp_test = train_test_split(X_pca_final, y, test_size=0.3, random_state=2137)

# %% [markdown]
# <h4> 12.1. Logistic Regression (PCA)
#     <a id="12.1."></a>

# %%
current_model = 'Logistic Regression (PCA)'
learning_model = "Learning Curve for " + current_model 
model = LogisticRegression(max_iter = 1500)
model.fit(Xp_train, yp_train)
# Out:
# LogisticRegression(max_iter=1500)

# %%
lrPCA_pred = model.predict(Xp_test)

# %%
lr_prediction = model.predict_proba(Xp_test)[:, 1]

# %% [markdown]
# <h5> 12.1.1. Visualization of ROC Curve
#     <a id="12.1.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(yp_test, lr_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Logistic Regression(PCA)')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
lr_aucPCA = roc_auc_score(yp_test, lr_prediction)
print('ROC AUC : {:.4f}'.format(lr_aucPCA))
plt.show()
# Out:
# ROC AUC : 0.8793

# %%
confusion_matrix(yp_test, lrPCA_pred)
# Out:
# array([[8150, 1718],
#        [1865, 8069]], dtype=int64)

# %%
performance_report = classification_report(yp_test, lrPCA_pred, output_dict=True)

performance_report
# Out:
# {'0': {'precision': 0.8137793310034948,
#   'recall': 0.825901905147953,
#   'f1-score': 0.8197958054619525,
#   'support': 9868},
#  '1': {'precision': 0.8244610197200368,
#   'recall': 0.8122609220857661,
#   'f1-score': 0.8183155012423305,
#   'support': 9934},
#  'accuracy': 0.8190586809413191,
#  'macro avg': {'precision': 0.8191201753617658,
#   'recall': 0.8190814136168596,
#   'f1-score': 0.8190556533521416,
#   'support': 19802},
#  'weighted avg': {'precision': 0.819137976378211,
#   'recall': 0.8190586809413191,
#   'f1-score': 0.8190531864276265,
#   'support': 19802}}

# %%
evaluatePCA(yp_test, lrPCA_pred)
# Out:
# {'f1-score': 0.82, 'accuracy': 0.82}

# %%
evaluate(y_test, lr_pred)
# Out:
# {'f1-score': 0.9, 'accuracy': 0.89}

# %% [markdown]
# <h5> 12.1.2. Model Summary
#     <a id="12.1.2."></a>

# %%
model_summary = evaluatePCA(yp_test, lrPCA_pred)
model_summary['model'] = current_model
model_summary['auroc'] = lr_auc
model_summary['auroc(PCA)'] = lr_aucPCA

pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                      model     auroc  auroc(PCA)
# 0      0.82      0.82  Logistic Regression (PCA)  0.930768    0.879305

# %% [markdown]
# ROC AUC score of Logistic Regression is higher before PCA.

# %% [markdown]
# <h4> 12.2. Decision Tree(PCA)
#     <a id="12.2."></a>

# %%
current_model = 'Decision Tree (PCA)'
learning_model = "Learning Curve for " + current_model 
model = DecisionTreeClassifier(max_depth=13)
model.fit(Xp_train, yp_train)
# Out:
# DecisionTreeClassifier(max_depth=13)

# %%
model.predict(Xp_test)
# Out:
# array([1, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
tree.plot_tree(model)
# Out:
# [Text(143.00664865654207, 209.6742857142857, 'X[0] <= -0.649\ngini = 0.5\nsamples = 46204\nvalue = [23135, 23069]'),
#  Text(52.251998393691586, 194.14285714285714, 'X[4] <= -0.787\ngini = 0.336\nsamples = 20407\nvalue = [16052, 4355]'),
#  Text(24.72743428738318, 178.61142857142858, 'X[8] <= -0.055\ngini = 0.466\nsamples = 3978\nvalue = [1470, 2508]'),
#  Text(12.572111565420562, 163.07999999999998, 'X[4] <= -1.357\ngini = 0.344\nsamples = 2752\nvalue = [608, 2144]'),
#  Text(3.2723831775700933, 147.54857142857142, 'X[1] <= 0.845\ngini = 0.223\nsamples = 1221\nvalue = [156, 1065]'),
#  Text(1.4341121495327103, 132.01714285714286, 'X[0] <= -3.23\ngini = 0.153\nsamples = 768\nvalue = [64, 704]'),
#  Text(0.417196261682243, 116.48571428571428, 'X[7] <= -1.3\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2085981308411215, 100.9542857142857, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
# ...

# %%
dt_prediction = model.predict(Xp_test)

# %%
confusion_matrix(yp_test, dt_prediction)
# Out:
# array([[8258, 1610],
#        [ 908, 9026]], dtype=int64)

# %%
print(classification_report(yp_test,dt_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      9868
#            1       0.85      0.91      0.88      9934
#
#     accuracy                           0.87     19802
#    macro avg       0.87      0.87      0.87     19802
# weighted avg       0.87      0.87      0.87     19802

# %%
dtree_pr= evaluatePCA(dt_prediction,yp_test)
dtree_pr
# Out:
# {'f1-score': 0.88, 'accuracy': 0.87}

# %% [markdown]
# <h5> 12.2.1. Visualization of ROC Curve
#     <a id="12.2.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(yp_test, dt_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Decision Tree classifier(PCA)')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
dt_aucPCA = roc_auc_score(yp_test, dt_prediction)
print('ROC AUC : {:.4f}'.format(dt_aucPCA))
plt.show()
# Out:
# ROC AUC : 0.8727

# %% [markdown]
# <h5> 12.2.2. Model Summary
#     <a id="12.2.2."></a>

# %%
model_summary = evaluate(yp_test, dt_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = dt_auc
model_summary['auroc(PCA)'] = dt_aucPCA

pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                model     auroc  auroc(PCA)
# 0      0.88      0.87  Decision Tree (PCA)  0.871491    0.872722

# %% [markdown]
# Decision Tree has almost equal ROC AUC score - model after PCA decomposition has higher score.

# %% [markdown]
# <h4> 12.3. Random Forest(PCA)
#     <a id="12.3."></a>

# %%
current_model = 'Random Forest Classifier (PCA)'
learning_model = "Learning Curve for " + current_model 
model = RandomForestClassifier(n_estimators=25)
model.fit(Xp_train, yp_train)
# Out:
# RandomForestClassifier(n_estimators=25)

# %%
rf_prediction = model.predict(Xp_test)

# %%
yp_pred = model.predict(Xp_test)
confusion_matrix(yp_test, rf_prediction)
# Out:
# array([[8195, 1673],
#        [ 256, 9678]], dtype=int64)

# %%
print(classification_report(yp_test,rf_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89      9868
#            1       0.85      0.97      0.91      9934
#
#     accuracy                           0.90     19802
#    macro avg       0.91      0.90      0.90     19802
# weighted avg       0.91      0.90      0.90     19802

# %%
rf_pr = evaluatePCA(rf_prediction,yp_test)
print(rf_pr)
# Out:
# {'f1-score': 0.91, 'accuracy': 0.9}

# %% [markdown]
# <h5> 12.3.1. Visualization of ROC Curve
#     <a id="12.3.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(yp_test, rf_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Rain Forest classifier(PCA)')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
rf_aucPCA = roc_auc_score(yp_test, rf_prediction)
print('ROC AUC : {:.4f}'.format(rf_aucPCA))
plt.show()
# Out:
# ROC AUC : 0.9023

# %% [markdown]
# <h5> 12.3.2. Model Summary
#     <a id="12.3.2."></a>

# %%
model_summary = evaluatePCA(yp_test, rf_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = rf_auc
model_summary['auroc(PCA)'] = rf_aucPCA
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                           model     auroc  auroc(PCA)
# 0      0.91       0.9  Random Forest Classifier (PCA)  0.905606    0.902346

# %% [markdown]
# ROC AUC score of both Random Forest models are almost equal. Model trained before PCA has slightly higher score.

# %% [markdown]
# <h4> 12.4. SVM(PCA)
#     <a id="12.4."></a>

# %%
current_model = 'SVM (PCA)'
model = SVC()
model.fit(Xp_train,yp_train)
# Out:
# SVC()

# %%
svm_prediction = model.predict(Xp_test)

# %%
yp_pred = model.predict(Xp_test)
confusion_matrix(yp_test, svm_prediction)
# Out:
# array([[7778, 2090],
#        [ 217, 9717]], dtype=int64)

# %%
print(classification_report(yp_test,svm_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87      9868
#            1       0.82      0.98      0.89      9934
#
#     accuracy                           0.88     19802
#    macro avg       0.90      0.88      0.88     19802
# weighted avg       0.90      0.88      0.88     19802

# %%
svm_pr = evaluatePCA(svm_prediction,yp_test)
svm_pr
# Out:
# {'f1-score': 0.89, 'accuracy': 0.88}

# %% [markdown]
# <h5> 12.4.1. Visualization of ROC Curve
#     <a id="12.4.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(yp_test, svm_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a SVM classifier(PCA)')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
svm_aucPCA = roc_auc_score(yp_test, svm_prediction)
print('ROC AUC : {:.4f}'.format(svm_aucPCA))
plt.show()
# Out:
# ROC AUC : 0.8832

# %% [markdown]
# <h5> 12.4.2. Model Summary
#     <a id="12.4.2."></a>

# %%
model_summary = evaluatePCA(yp_test, svm_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = svm_auc
model_summary['auroc(PCA)'] = svm_aucPCA
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy      model     auroc  auroc(PCA)
# 0      0.89      0.88  SVM (PCA)  0.899488     0.88318

# %% [markdown]
# SVM before PCA has higher ROC AUC score.

# %% [markdown]
# <h4> 12.5. K Nearest Neighbors Classifier (PCA)
#     <a id="12.5."></a>

# %%
current_model = 'K Nearest Neighbors Classifier (PCA)'
model = KNeighborsClassifier(n_neighbors=5)
model.fit(Xp_train, yp_train)
# Out:
# KNeighborsClassifier()

# %%
knn_prediction = model.predict(Xp_test)

# %%
yp_pred = model.predict(Xp_test)
confusion_matrix(yp_test, knn_prediction)
# Out:
# array([[8223, 1645],
#        [ 635, 9299]], dtype=int64)

# %%
print(classification_report(knn_prediction,yp_test))
knn_pr = evaluatePCA(knn_prediction,yp_test)
knn_pr
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      8858
#            1       0.94      0.85      0.89     10944
#
#     accuracy                           0.88     19802
#    macro avg       0.88      0.89      0.88     19802
# weighted avg       0.89      0.88      0.89     19802
# {'f1-score': 0.89, 'accuracy': 0.88}

# %% [markdown]
# <h5> 12.5.1. Visualization of ROC Curve
#     <a id="12.5.1."></a>

# %%
fpr, tpr, thresholds = roc_curve(yp_test, knn_prediction)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a K Nearest Neighbors Classifier(PCA)')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
knn_aucPCA = roc_auc_score(yp_test, knn_prediction)
print('ROC AUC : {:.4f}'.format(knn_aucPCA))
plt.show()
# Out:
# ROC AUC : 0.8847

# %% [markdown]
# <h5> 12.5.2. Model Summary
#     <a id="12.5.2."></a>

# %%
model_summary = evaluatePCA(yp_test, knn_prediction)
model_summary['model'] = current_model
model_summary['auroc'] = knn_auc
model_summary['auroc(PCA)'] = knn_aucPCA
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                                 model     auroc  \
# 0      0.89      0.88  K Nearest Neighbors Classifier (PCA)  0.891017
#
#    auroc(PCA)
# 0    0.884689

# %% [markdown]
# KNN before PCA has higher ROC AUC score.

# %% [markdown]
# <h2> 13. Summary of all models
#     <a id="13."></a>

# %%
prediction_data={'Model':['Logistic Regression',
                          'Decision Tree',
                          'Random Forest',
                          'SVM',
                          'KNN'
                         ],
                    'ROC AUC':[lr_auc,
                              dt_auc, 
                              rf_auc,
                              svm_auc,
                              knn_auc],
                    'ROC AUC(PCA)':[lr_aucPCA,
                              dt_aucPCA, 
                              rf_aucPCA,
                              svm_aucPCA,
                              knn_aucPCA]                 
                    }
 
# Create DataFrame
prediction_table = pd.DataFrame(prediction_data)
prediction_table
# Out:
#                  Model   ROC AUC  ROC AUC(PCA)
# 0  Logistic Regression  0.930768      0.879305
# 1        Decision Tree  0.871491      0.872722
# 2        Random Forest  0.905606      0.902346
# 3                  SVM  0.899488      0.883180
# 4                  KNN  0.891017      0.884689

# %% [markdown]
# <b><u>c) Sprawdź działanie wcześniej użytych metod na skompresowanych danych za pomocą PCA, porównaj wyniki (AUROC score) z modelamiwytrenowanymi w poprzednim podpunkcie. (20pkt)

# %% [markdown]
# Decision Tree is slightly better after PCA transpose, on the other hand Logistic Regression is better before PCA and that's the highest ROC AUC score. Random Forest, SVM and KNN are almost equal with and without PCA transpose. I'll use Logistic Regression to train my Final Model.

# %% [markdown]
# <h2> 14. Final Model
#     <a id="14."></a>

# %% [markdown]
# d) Zbuduj finalny model, którego AUROC score będzie >= 80%, pamiętaj o doborze istotnych zmiennych,kroswalidacji oraz dostrojeniu parametrów modelu,pomyśl również o zbalansowaniu klas. (40pkt)

# %% [markdown]
# I'll use all features which I selected for Model Training section plus features added during Clastering.

# %%
loans.shape
# Out:
# (66006, 26)

# %%
Xf = loans.drop(['loan_status'], axis=1)
yf = loans['loan_status']

# %%
scaler = StandardScaler()
X_scaledFinal = scaler.fit_transform(Xf)

# %%
fX_train, fX_test, fy_train, fy_test = train_test_split(X_scaledFinal, yf, test_size=0.3, random_state=2137)

# %%
current_model = 'Logistic Regression Final Model'
learning_model = "Learning Curve for " + current_model 
model = LogisticRegression(max_iter = 1000)
model.fit(fX_train, fy_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lrFinal = model.predict(fX_test)

# %%
lr_predictionFinal = model.predict_proba(fX_test)[:, 1]

# %%
fpr, tpr, thresholds = roc_curve(y_test, lr_predictionFinal)
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, linewidth=2)
plt.plot([0,1], [0,1], 'k--' )
plt.hlines(y=0.80, xmax=1, xmin=0, colors="g", linestyles="--")
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Predicting a Logistic Regression')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
lr_aucFinal = roc_auc_score(y_test, lr_predictionFinal)
print('ROC AUC : {:.4f}'.format(lr_aucFinal))
plt.show()
# Out:
# ROC AUC : 0.9309

# %%
confusion_matrix(fy_test, lrFinal)
# Out:
# array([[7984, 1884],
#        [ 219, 9715]], dtype=int64)

# %%
print(classification_report(fy_test,lrFinal))

lr_pr= evaluate(lrFinal, fy_test)
lr_pr
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88      9868
#            1       0.84      0.98      0.90      9934
#
#     accuracy                           0.89     19802
#    macro avg       0.91      0.89      0.89     19802
# weighted avg       0.91      0.89      0.89     19802
# {'f1-score': 0.9, 'accuracy': 0.89}

# %%
model_summary = evaluate(fy_test, lrFinal)
model_summary['model'] = current_model
model_summary['auroc'] = lr_auc
model_summary['auroc - Final'] = lr_aucFinal
pd.DataFrame([model_summary])
# Out:
#    f1-score  accuracy                            model     auroc  \
# 0       0.9      0.89  Logistic Regression Final Model  0.930768
#
#    auroc - Final
# 0       0.930874

# %% [markdown]
# There is no difference (0.0001) between model trained in Model Training section and Final Model even when there is added 3 features from Clustering.

# %% [markdown]
# <h2> 15. Conclusions
#     <a id="15."></a>

# %% [markdown]
# I applied machine learning methods in prediction the probability that loan will be charged off. I chcecked 5 models (Logistic regression, Decision tree, Random forest, SVM, KNN) without and with PCA decomposition. I used as a Final model Logistic regression, because had the highest ROC AUC score and good learning curve. Final model ROC AUC score is equal as model trained before.
